# %% [markdown]
# <a href="https://colab.research.google.com/github/Muen1/multilingual-health-qa-africa/blob/main/notebooks/03_finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELL 0 — Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
import os

BASE_DIR = '/content/drive/MyDrive/multilingual_health_qa'
DATA_DIR = f'{BASE_DIR}/data'
OUT_DIR  = f'{BASE_DIR}/outputs'
PLOT_DIR = f'{BASE_DIR}/plots'
SUB_DIR  = f'{BASE_DIR}/submissions'

for d in [OUT_DIR, PLOT_DIR]:
    os.makedirs(d, exist_ok=True)

print("Drive mounted.")
print("Data files:", os.listdir(DATA_DIR))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted.
# Data files: ['Train.csv', 'Val.csv', 'Test.csv', 'SampleSubmission.csv', 'train_clean.csv', 'val_clean.csv', 'test_clean.csv', 'predictions_exp01_mt5small_zeroshot.csv', 'experiment_log.json']

# %%
# CELL S2 — Install only what's missing (compatible with Colab's pre-installed versions)
# !pip install -q evaluate rouge-score sentencepiece

# Verify
import importlib
packages = ['transformers', 'datasets', 'peft', 'accelerate', 'evaluate', 'rouge_score', 'sentencepiece']
print("\n=== Installed versions ===")
for p in packages:
    try:
        mod = importlib.import_module(p)
        ver = getattr(mod, '__version__', 'installed')
        print(f"  ✓ {p}: {ver}")
    except:
        print(f"  ✗ {p}: MISSING")

print("\nInstallation complete — no restart needed.")
# Out:
# === Installed versions ===
#   ✓ transformers: 5.10.2
#   ✓ datasets: 4.0.0
#   ✓ peft: 0.19.1
#   ✓ accelerate: 1.13.0
#   ✓ evaluate: 0.4.6
#   ✓ rouge_score: installed
#   ✓ sentencepiece: 0.2.1
#
# Installation complete — no restart needed.

# %%
# CELL S3 — Package check
import importlib, sys

required = {
    'transformers': '4.0',
    'datasets': '2.0',
    'peft': '0.5',
    'accelerate': '0.20',
    'evaluate': '0.4',
    'rouge_score': '0.1',
    'sentencepiece': '0.1',
}

print("=== Package check ===")
all_ok = True
for pkg, min_ver in required.items():
    try:
        mod = importlib.import_module(pkg)
        ver = getattr(mod, '__version__', '?')
        print(f"  ✓ {pkg}: {ver}")
    except ImportError:
        print(f"  ✗ {pkg}: MISSING")
        all_ok = False

if all_ok:
    print("\n✓ All packages present — ready to continue.")
else:
    print("\n✗ Run: !pip install -q evaluate rouge-score sentencepiece")
# Out:
# === Package check ===
#   ✓ transformers: 5.10.2
#   ✓ datasets: 4.0.0
#   ✓ peft: 0.19.1
#   ✓ accelerate: 1.13.0
#   ✓ evaluate: 0.4.6
#   ✓ rouge_score: ?
#   ✓ sentencepiece: 0.2.1
#
# ✓ All packages present — ready to continue.

# %%
# imports
import gc
import os
import json
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import evaluate as hf_evaluate
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq,
    EarlyStoppingCallback
)
from peft import get_peft_model, LoraConfig, TaskType
from datasets import Dataset

print("PyTorch version :", torch.__version__)
print("CUDA available  :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU             :", torch.cuda.get_device_name(0))
else:
    print("WARNING: No GPU detected. Go to Runtime → Change runtime type → T4 GPU")
# Out:
# PyTorch version : 2.11.0+cu128
# CUDA available  : True
# GPU             : Tesla T4

# %%
# CELL S4 — Load cleaned data
train = pd.read_csv(f'{DATA_DIR}/train_clean.csv')
val   = pd.read_csv(f'{DATA_DIR}/val_clean.csv')
test  = pd.read_csv(f'{DATA_DIR}/test_clean.csv')

# Column mapping for this dataset
q_col    = 'input'
a_col    = 'output'
lang_col = 'subset'
id_col   = 'ID'

# Rebuild prompts v1 if missing
if 'input_text' not in train.columns:
    def _prompt_v1(q, l):
        return f"Language: {l}\nQuestion: {q}\nAnswer:"
    train['input_text']  = train.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)
    train['target_text'] = train[a_col].astype(str)
    val['input_text']    = val.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)
    val['target_text']   = val[a_col].astype(str)
    test['input_text']   = test.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)

print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")
print("Sample input:", train['input_text'].iloc[0])
print("Sample target:", train['target_text'].iloc[0][:150])
# Out:
# Train: 29814, Val: 6686, Test: 2618
# Sample input: Language: Aka_Gha
# Question: Ɔkwan bɛn so na mmabunbɛtumi aboa wɔn mfɛfoɔ a nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ? Yei bi ne sɛnea wɔbɛkyekye wɔn werɛ, sɛnea wɔbɛboa wɔn ma wɔanya mmoa firi nnwumakuo a ɛfata hɔ, ne sɛnea wɔbɛsiw afɔbu suban ne nsɛm a nkurɔfoɔ de gu oyarefoɔ no so no kwan.
# Answer:
# Sample target: Mmabun betumi aboa atipɛnfo a ebia nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ so denam: Nkate fam mmoa a wɔde bɛma na wɔagye wɔn nkate atom a wɔremmu atɛ

# %%
# CELL S5 — Load sample submission and verify format
sample = pd.read_csv(f'{DATA_DIR}/SampleSubmission.csv')
print(" Sample submission loaded")
print(f"  Columns : {sample.columns.tolist()}")
print(f"  Shape   : {sample.shape}")
print(f"\nFirst 2 rows:")
print(sample.head(2).to_string())
# Out:
#  Sample submission loaded
#   Columns : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#   Shape   : (2618, 4)
#
# First 2 rows:
#                        ID             TargetRLF1             TargetR1F1              TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  Wuna dey craze, eweeh  Wuna dey craze, eweeh  Wuna dey craze, eweeh
# 1  ID_TS_Aka_Gha_1C80317F  Wuna dey craze, eweeh  Wuna dey craze, eweeh  Wuna dey craze, eweeh

# %%
# CELL S6 — All shared helper functions

#  1. ROUGE metric
rouge_metric = hf_evaluate.load("rouge")

#  2. Tokenize datasets
def get_tokenized_datasets(tokenizer, train_df, val_df,
                            max_input=256, max_target=256):
    def preprocess(examples):
        inputs = tokenizer(
            examples['input_text'],
            max_length=max_input,
            truncation=True,
            padding='max_length'
        )
        targets = tokenizer(
            examples['target_text'],
            max_length=max_target,
            truncation=True,
            padding='max_length'
        )
        labels = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label]
            for label in targets['input_ids']
        ]
        inputs['labels'] = labels
        return inputs

    train_ds  = Dataset.from_pandas(
        train_df[['input_text','target_text']].reset_index(drop=True))
    val_ds    = Dataset.from_pandas(
        val_df[['input_text','target_text']].reset_index(drop=True))
    train_tok = train_ds.map(preprocess, batched=True,
                             remove_columns=['input_text','target_text'])
    val_tok   = val_ds.map(preprocess,   batched=True,
                           remove_columns=['input_text','target_text'])
    return train_tok, val_tok

# 3. Compute metrics
def make_compute_metrics(tokenizer):
    def compute_metrics(eval_preds):
        preds, labels = eval_preds
        if isinstance(preds, tuple):
            preds = preds[0]

        preds  = np.where(preds  != -100, preds,  tokenizer.pad_token_id)
        labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
        preds  = np.clip(preds, 0, tokenizer.vocab_size - 1)

        decoded_preds  = tokenizer.batch_decode(
            preds,  skip_special_tokens=True)
        decoded_labels = tokenizer.batch_decode(
            labels, skip_special_tokens=True)
        decoded_preds  = [p.strip() for p in decoded_preds]
        decoded_labels = [l.strip() for l in decoded_labels]
        result = rouge_metric.compute(
            predictions=decoded_preds,
            references=decoded_labels,
            use_stemmer=True
        )
        return {
            "rouge1": round(result["rouge1"], 4),
            "rougeL": round(result["rougeL"], 4)
        }
    return compute_metrics

# 4. Training
def run_training(model, tokenizer, train_tok, val_tok,
                 experiment_name, learning_rate,
                 num_epochs, batch_size, max_target_len):
    args = Seq2SeqTrainingArguments(
        output_dir=f"{OUT_DIR}/checkpoints_{experiment_name}",
        num_train_epochs=num_epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        gradient_accumulation_steps=4,
        warmup_steps=100,
        learning_rate=learning_rate,
        weight_decay=0.01,
        fp16=True,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="eval_loss",
        predict_with_generate=True,
        generation_max_length=max_target_len,
        logging_steps=50,
        report_to="none",
        push_to_hub=False
    )
    collator = DataCollatorForSeq2Seq(tokenizer, model=model, padding=True)
    trainer  = Seq2SeqTrainer(
        model=model,
        args=args,
        train_dataset=train_tok,
        eval_dataset=val_tok,
        processing_class=tokenizer,
        data_collator=collator,
        compute_metrics=make_compute_metrics(tokenizer),
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
    )
    est = len(train_tok) * num_epochs / (batch_size * 4) / 60
    print(f" Estimated time : ~{est:.0f} minutes")
    print("Starting training...")
    trainer.train()
    return trainer

# 5. Save model
def save_model(model, tokenizer, experiment_name):
    path = f'{OUT_DIR}/model_{experiment_name}'
    os.makedirs(path, exist_ok=True)
    model.save_pretrained(path)
    tokenizer.save_pretrained(path)
    print(f" Model saved : {path}")
    return path

# 6. Generate answers
def generate_answers(model, tokenizer, texts,
                     max_input=256, max_target=256,
                     batch_size=16, num_beams=4):
    model.eval()
    if torch.cuda.is_available():
        model = model.cuda()
    all_answers = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Generating"):
        batch  = texts[i:i+batch_size]
        inputs = tokenizer(
            batch, return_tensors='pt',
            max_length=max_input,
            truncation=True, padding=True
        )
        if torch.cuda.is_available():
            inputs = {k: v.cuda() for k, v in inputs.items()}
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_target,
                num_beams=num_beams,
                no_repeat_ngram_size=3,
                length_penalty=1.0
            )
        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        all_answers.extend(decoded)
    return all_answers

# 7. Save predictions
def save_predictions(test_df, answers, experiment_name):
    out              = test_df.copy()
    out['predicted_answer'] = answers
    path             = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    out.to_csv(path, index=False)
    print(f" Predictions saved : {path}")
    return path

# 8. Build Zindi submission
def build_submission(experiment_name):
    pred_path = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    if not os.path.exists(pred_path):
        print(f"✗ No predictions found for {experiment_name}")
        print(f"  Expected at: {pred_path}")
        return None

    preds       = pd.read_csv(pred_path)
    pred_id_col = preds.columns[0]
    pred_answer = preds['predicted_answer'].astype(str).values

    submission  = pd.DataFrame({
        'ID':         preds[pred_id_col].values,
        'TargetRLF1': pred_answer,
        'TargetR1F1': pred_answer,
        'TargetLLM':  pred_answer
    })

    assert list(submission.columns) == ['ID','TargetRLF1','TargetR1F1','TargetLLM'], \
        "Column mismatch!"
    assert len(submission) == len(sample), \
        f"Row mismatch: {len(submission)} vs {len(sample)}"
    assert submission.isnull().sum().sum() == 0, \
        "Null values found!"

    path = f'{SUB_DIR}/submission_{experiment_name}.csv'
    submission.to_csv(path, index=False)
    print(f" Submission saved  : {path}")
    print(f"  Shape             : {submission.shape}")
    print(f"  Columns           : {submission.columns.tolist()}")
    print(f"\nFirst 3 rows:")
    print(submission.head(3).to_string())
    return path

# 9. Plot learning curves
def plot_learning_curves(trainer, experiment_name):
    log      = trainer.state.log_history
    t_steps  = [x['step']      for x in log
                if 'loss' in x and 'eval_loss' not in x]
    t_losses = [x['loss']      for x in log
                if 'loss' in x and 'eval_loss' not in x]
    e_epochs = [x['epoch']     for x in log if 'eval_loss' in x]
    e_losses = [x['eval_loss'] for x in log if 'eval_loss' in x]
    e_r1     = [x.get('eval_rouge1', 0) for x in log if 'eval_loss' in x]
    e_rL     = [x.get('eval_rougeL', 0) for x in log if 'eval_loss' in x]

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(f'Learning Curves — {experiment_name}',
                 fontsize=13, fontweight='bold')

    axes[0].plot(t_steps, t_losses, color='royalblue', linewidth=1.5)
    axes[0].set_title('Training Loss')
    axes[0].set_xlabel('Step')
    axes[0].set_ylabel('Loss')
    axes[0].grid(True, alpha=0.4)

    axes[1].plot(e_epochs, e_losses, color='darkorange',
                 marker='o', linewidth=2)
    axes[1].set_title('Validation Loss per Epoch')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Eval Loss')
    axes[1].grid(True, alpha=0.4)

    axes[2].plot(e_epochs, e_r1, color='green',
                 marker='o', linewidth=2, label='ROUGE-1')
    axes[2].plot(e_epochs, e_rL, color='purple',
                 marker='s', linewidth=2, label='ROUGE-L')
    axes[2].set_title('ROUGE Scores per Epoch')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('F1 Score')
    axes[2].legend()
    axes[2].grid(True, alpha=0.4)

    plt.tight_layout()
    path = f'{PLOT_DIR}/learning_curves_{experiment_name}.png'
    plt.savefig(path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"✓ Learning curves saved : {path}")

#  10. Experiment log
LOG_PATH = f'{DATA_DIR}/experiment_log.json'

def save_experiment_log(experiment_name, config, metrics):
    log = {}
    if os.path.exists(LOG_PATH):
        with open(LOG_PATH, 'r') as f:
            log = json.load(f)
    log[experiment_name] = {"config": config, "metrics": metrics}
    with open(LOG_PATH, 'w') as f:
        json.dump(log, f, indent=2)
    print(f"✓ Experiment log updated : {LOG_PATH}")
    print(json.dumps(log[experiment_name], indent=2))

def update_zindi_score(experiment_name, score):
    if not os.path.exists(LOG_PATH):
        print("No log file found. Run the experiment first.")
        return
    with open(LOG_PATH, 'r') as f:
        log = json.load(f)
    if experiment_name not in log:
        print(f"Experiment {experiment_name} not in log.")
        return
    log[experiment_name]['metrics']['zindi_score'] = score
    with open(LOG_PATH, 'w') as f:
        json.dump(log, f, indent=2)
    print(f"✓ Zindi score updated: {experiment_name} = {score}")

# 11. Check if already done
def is_done(experiment_name):
    pred_path = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    if os.path.exists(pred_path):
        print(f"✓ ALREADY DONE: {experiment_name}")
        print(f"  Predictions at: {pred_path}")
        print("  Skipping to submission cell.")
        return True
    print(f" NOT YET DONE: {experiment_name} — will run now.")
    return False

# 12. Free GPU memory
def free_gpu(*objects):
    for obj in objects:
        del obj
    gc.collect()
    torch.cuda.empty_cache()
    if torch.cuda.is_available():
        used = torch.cuda.memory_allocated() / 1e9
        free = torch.cuda.mem_get_info()[0] / 1e9
        print(f" GPU memory freed")
        print(f"  Used : {used:.2f} GB")
        print(f"  Free : {free:.2f} GB")

print("✓ All helper functions loaded and ready.")
# Out:
# ✓ All helper functions loaded and ready.

# %%
# CELL S7 — Check what experiments are already done
import os, json

print("=== EXPERIMENT STATUS ===\n")

experiments_list = [
    "exp01_mt5small_zeroshot",
    "exp02_mt5small_lora_r16",
    "exp03_flanT5base_lora_r16",
    "exp04_flanT5base_lora_r32",
    "exp05_flanT5base_promptv2",
    "exp06_flanT5large_lora_r16"
]

for exp in experiments_list:
    pred_path = f'{DATA_DIR}/predictions_{exp}.csv'
    sub_path  = f'{DATA_DIR}/../submissions/submission_{exp}.csv'
    done      = "✓ DONE" if os.path.exists(pred_path) else "✗ NOT DONE"
    submitted = "✓ SUBMITTED" if os.path.exists(sub_path) else "✗ NOT SUBMITTED"
    print(f"{exp}")
    print(f"  Predictions : {done}")
    print(f"  Submission  : {submitted}")
    print()

if os.path.exists(LOG_PATH):
    print("=== SCORES SO FAR ===")
    with open(LOG_PATH, 'r') as f:
        log = json.load(f)
    for name, entry in log.items():
        m = entry.get('metrics', {})
        print(f"  {name}")
        print(f"    ROUGE-1    : {m.get('val_rouge1', 'N/A')}")
        print(f"    ROUGE-L    : {m.get('val_rougeL', 'N/A')}")
        print(f"    Zindi Score: {m.get('zindi_score', 'not yet')}")
        print()
else:
    print("No experiment log yet — starting fresh.")
# Out:
# === EXPERIMENT STATUS ===
#
# exp01_mt5small_zeroshot
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp02_mt5small_lora_r16
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp03_flanT5base_lora_r16
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp04_flanT5base_lora_r32
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp05_flanT5base_promptv2
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp06_flanT5large_lora_r16
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# === SCORES SO FAR ===
#   exp02_mt5small_lora_r16
#     ROUGE-1    : pending
#     ROUGE-L    : pending
#     Zindi Score: pending

# %%
# EXPERIMENT 1 — mt5-small Zero-Shot (No Training)
# WHAT    : Run mt5-small on test set without any fine-tuning
# WHY     : Establishes a baseline. Shows how badly the model
#           performs without task-specific training. All other
#           experiments are compared against this score.
# CHANGE  : Nothing — pure zero-shot inference

EXP1 = "exp01_mt5small_zeroshot"

if not is_done(EXP1):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 1 : {EXP1}")
    print(f"Model        : google/mt5-small")
    print(f"Training     : NONE (zero-shot)")
    print(f"{'='*60}\n")

    # Load model
    tok1   = AutoTokenizer.from_pretrained("google/mt5-small")
    model1 = AutoModelForSeq2SeqLM.from_pretrained("google/mt5-small")
    print(f"Parameters : {model1.num_parameters():,}")

    # Zero-shot inference on test set
    print("\nRunning zero-shot inference on test set...")
    answers1 = generate_answers(
        model1, tok1,
        test['input_text'].tolist(),
        max_input=256, max_target=256,
        batch_size=16, num_beams=4
    )
    save_predictions(test, answers1, EXP1)

    # Evaluate on validation set for local ROUGE score
    print("\nEvaluating on validation set...")
    val_ans1 = generate_answers(
        model1, tok1,
        val['input_text'].tolist(),
        max_input=256, max_target=256,
        batch_size=16, num_beams=4
    )
    r1 = rouge_metric.compute(
        predictions=[a.strip() for a in val_ans1],
        references=[str(t).strip() for t in val['target_text'].tolist()],
        use_stemmer=True
    )
    print(f"\n✓ Val ROUGE-1 : {r1['rouge1']:.4f}")
    print(f"✓ Val ROUGE-L : {r1['rougeL']:.4f}")

    # Save to experiment log
    save_experiment_log(
        EXP1,
        config={
            "model": "google/mt5-small",
            "lora": False,
            "training": False,
            "prompt_version": "v1",
            "purpose": "Zero-shot baseline"
        },
        metrics={
            "val_rouge1": round(r1['rouge1'], 4),
            "val_rougeL": round(r1['rougeL'], 4),
            "zindi_score": "pending"
        }
    )

    # Free GPU memory before next experiment
    free_gpu(model1, tok1)
    print(f"\n{'='*60}")
    print("EXPERIMENT 1 COMPLETE")
    print(f"{'='*60}")
# Out:
# ✓ ALREADY DONE: exp01_mt5small_zeroshot
#   Predictions at: /content/drive/MyDrive/multilingual_health_qa/data/predictions_exp01_mt5small_zeroshot.csv
#   Skipping to submission cell.

# %%
# EXPERIMENT 1 — Build submission and download
sub_path1 = build_submission(EXP1)
files.download(sub_path1)
print("\n NEXT STEPS:")
print("1. Go to Zindi competition → Submit tab")
print("2. Upload the downloaded file")
print("3. Comment: 'Exp 1: mt5-small zero-shot baseline'")
print("4. Wait for score → screenshot it")
print("5. Run the cell below with your real score")
# Out:
#  Submission saved  : /content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp01_mt5small_zeroshot.csv
#   Shape             : (2618, 4)
#   Columns           : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#
# First 3 rows:
#                        ID       TargetRLF1       TargetR1F1        TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D    <extra_id_0>.    <extra_id_0>.    <extra_id_0>.
# 1  ID_TS_Aka_Gha_1C80317F  <extra_id_0>?e蝾  <extra_id_0>?e蝾  <extra_id_0>?e蝾
# 2  ID_TS_Aka_Gha_06671AD1    <extra_id_0>.    <extra_id_0>.    <extra_id_0>.
#  NEXT STEPS:
# 1. Go to Zindi competition → Submit tab
# 2. Upload the downloaded file
# 3. Comment: 'Exp 1: mt5-small zero-shot baseline'
# 4. Wait for score → screenshot it
# 5. Run the cell below with your real score

# %%
# EXPERIMENT 1 — Zindi score
ZINDI_SCORE_EXP1 = 0.00167

update_zindi_score(EXP1, ZINDI_SCORE_EXP1)
print(f"\nExp 1 score recorded: {ZINDI_SCORE_EXP1}")
print("Now commit to GitHub, then scroll down to Experiment 2.")
# Out:
# No log file found. Run the experiment first.
#
# Exp 1 score recorded: 0.00167
# Now commit to GitHub, then scroll down to Experiment 2.

# %%
# FIX — Upgrade torchao to fix peft compatibility
# !pip install -q --upgrade torchao

# Restart runtime after this installs
import os
os.kill(os.getpid(), 9)

# %%
# Confirm torchao version is correct
import torchao
import peft
import torch

print(f"torchao : {torchao.__version__}")
print(f"peft    : {peft.__version__}")
print(f"torch   : {torch.__version__}")
print(f"GPU     : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NOT AVAILABLE'}")

# Quick test that get_peft_model works without the ImportError
from peft import LoraConfig, TaskType, get_peft_model
from transformers import AutoModelForSeq2SeqLM

print("\nTesting peft import...")
test_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
test_lora  = LoraConfig(task_type=TaskType.SEQ_2_SEQ_LM, r=8, lora_alpha=16,
                         target_modules=["q", "v"], bias="none")
test_model = get_peft_model(test_model, test_lora)
print("✓ get_peft_model works correctly")
print("✓ Ready to run experiments")

del test_model
# Out:
# torchao : 0.17.0
# peft    : 0.19.1
# torch   : 2.11.0+cu128
# GPU     : Tesla T4
#
# Testing peft import...
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ✓ get_peft_model works correctly
# ✓ Ready to run experiments

# %%
# EXPERIMENT 2 — mt5-small Fine-Tuned with LoRA r=16
# WHAT    : Fine-tune the same small model from Exp 1 with LoRA
# WHY     : Isolates the effect of fine-tuning. Same model as
#           Exp 1 so any score improvement comes purely from
#           training, not from a bigger model.
# CHANGE  : Added LoRA fine-tuning (r=16) vs Exp 1 zero-shot

EXP2 = "exp02_mt5small_lora_r16"

if not is_done(EXP2):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 2 : {EXP2}")
    print(f"Model        : google/mt5-small")
    print(f"LoRA         : r=16, alpha=32")
    print(f"LR / Epochs  : 3e-4 / 3")
    print(f"{'='*60}\n")

    tok2   = AutoTokenizer.from_pretrained("google/mt5-small")
    model2 = AutoModelForSeq2SeqLM.from_pretrained("google/mt5-small")

    lora2  = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=16, lora_alpha=32,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model2 = get_peft_model(model2, lora2)
    model2.print_trainable_parameters()

    train_tok2, val_tok2 = get_tokenized_datasets(
        tok2, train, val, max_input=256, max_target=256)

    trainer2 = run_training(
        model2, tok2, train_tok2, val_tok2,
        experiment_name=EXP2,
        learning_rate=3e-4, num_epochs=3,
        batch_size=8, max_target_len=256
    )

    save_model(model2, tok2, EXP2)
    plot_learning_curves(trainer2, EXP2)

    # Get final ROUGE from trainer log
    log2     = trainer2.state.log_history
    best2    = [x for x in log2 if 'eval_rouge1' in x]
    r1_2     = best2[-1]['eval_rouge1'] if best2 else 0.0
    rL_2     = best2[-1]['eval_rougeL'] if best2 else 0.0
    print(f"\n Val ROUGE-1 : {r1_2:.4f}")
    print(f" Val ROUGE-L : {rL_2:.4f}")

    # Inference on test set
    print("\nRunning inference on test set...")
    answers2 = generate_answers(
        model2, tok2,
        test['input_text'].tolist(),
        batch_size=16, num_beams=4
    )
    save_predictions(test, answers2, EXP2)

    save_experiment_log(
        EXP2,
        config={
            "model": "google/mt5-small",
            "lora": True, "lora_r": 16, "lora_alpha": 32,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 8, "prompt_version": "v1",
            "purpose": "Fine-tuning effect vs zero-shot"
        },
        metrics={
            "val_rouge1": round(r1_2, 4),
            "val_rougeL": round(rL_2, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model2, tok2, trainer2)
    print(f"\n{'='*60}")
    print("EXPERIMENT 2 COMPLETE")
    print(f"{'='*60}")
# Out:
#  NOT YET DONE: exp02_mt5small_lora_r16 — will run now.
#
# ============================================================
# EXPERIMENT 2 : exp02_mt5small_lora_r16
# Model        : google/mt5-small
# LoRA         : r=16, alpha=32
# LR / Epochs  : 3e-4 / 3
# ============================================================
# Loading weights:   0%|          | 0/192 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# trainable params: 688,128 || all params: 300,864,896 || trainable%: 0.2287
# Map:   0%|          | 0/29814 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6686 [00:00<?, ? examples/s]
#  Estimated time : ~47 minutes
# Starting training...
#     <div>
#
#       <progress value='2796' max='2796' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2796/2796 1:02:46, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rougel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.003400</td>
#       <td>0.003300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.003400</td>
#       <td>0.003300</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.003400</td>
#       <td>0.003300</td>
#     </tr>
#   </tbody>
# </table><p>
#  Model saved : /content/drive/MyDrive/multilingual_health_qa/outputs/model_exp02_mt5small_lora_r16
# ✓ Learning curves saved : /content/drive/MyDrive/multilingual_health_qa/plots/learning_curves_exp02_mt5small_lora_r16.png
#
#  Val ROUGE-1 : 0.0034
#  Val ROUGE-L : 0.0033
#
# Running inference on test set...
# Generating:   0%|          | 0/164 [00:00<?, ?it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 1/164 [00:00<02:09,  1.26it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 2/164 [00:01<01:42,  1.58it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 3/164 [00:01<01:31,  1.76it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 4/164 [00:02<01:21,  1.97it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 5/164 [00:02<01:18,  2.02it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▎         | 6/164 [00:03<01:23,  1.90it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▍         | 7/164 [00:03<01:22,  1.91it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▍         | 8/164 [00:04<01:21,  1.92it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▌         | 9/164 [00:04<01:19,  1.95it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▌         | 10/164 [00:05<01:24,  1.83it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 11/164 [00:06<01:29,  1.71it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 12/164 [00:06<01:22,  1.84it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 13/164 [00:07<01:24,  1.78it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▊         | 14/164 [00:07<01:23,  1.80it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 15/164 [00:08<01:29,  1.67it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|▉         | 16/164 [00:08<01:24,  1.75it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|█         | 17/164 [00:09<01:24,  1.73it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█         | 18/164 [00:10<01:23,  1.74it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 19/164 [00:11<01:42,  1.41it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 20/164 [00:11<01:44,  1.38it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 21/164 [00:12<01:29,  1.59it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 22/164 [00:12<01:21,  1.74it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▍        | 23/164 [00:13<01:11,  1.99it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▍        | 24/164 [00:13<01:17,  1.80it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▌        | 25/164 [00:14<01:16,  1.82it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 26/164 [00:14<01:15,  1.84it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▋        | 27/164 [00:15<01:15,  1.81it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 28/164 [00:15<01:18,  1.73it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 29/164 [00:16<01:16,  1.76it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 30/164 [00:17<01:13,  1.82it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▉        | 31/164 [00:17<01:18,  1.70it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|█▉        | 32/164 [00:18<01:07,  1.94it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|██        | 33/164 [00:18<01:06,  1.96it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██        | 34/164 [00:19<01:07,  1.93it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██▏       | 35/164 [00:19<01:09,  1.86it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 36/164 [00:19<00:58,  2.18it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 37/164 [00:20<00:46,  2.73it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 38/164 [00:20<00:48,  2.62it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 39/164 [00:21<01:08,  1.81it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 40/164 [00:21<01:02,  1.98it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▌       | 41/164 [00:22<00:57,  2.13it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 42/164 [00:22<01:05,  1.87it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 43/164 [00:23<01:18,  1.54it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 44/164 [00:24<01:18,  1.52it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 45/164 [00:24<01:06,  1.80it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 46/164 [00:25<00:59,  1.99it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▊       | 47/164 [00:25<00:58,  1.99it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▉       | 48/164 [00:26<00:56,  2.06it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|██▉       | 49/164 [00:26<00:52,  2.18it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|███       | 50/164 [00:27<00:53,  2.11it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███       | 51/164 [00:27<01:04,  1.76it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 52/164 [00:28<01:04,  1.74it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 53/164 [00:28<00:59,  1.86it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 54/164 [00:29<01:02,  1.75it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▎      | 55/164 [00:30<00:59,  1.85it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 56/164 [00:30<00:59,  1.83it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▍      | 57/164 [00:31<01:06,  1.61it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▌      | 58/164 [00:31<00:57,  1.84it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▌      | 59/164 [00:32<00:52,  2.01it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 60/164 [00:32<00:44,  2.33it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 61/164 [00:32<00:43,  2.39it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 62/164 [00:33<00:52,  1.95it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 63/164 [00:33<00:49,  2.03it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▉      | 64/164 [00:34<00:44,  2.25it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|███▉      | 65/164 [00:34<00:42,  2.35it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|████      | 66/164 [00:35<00:40,  2.43it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 67/164 [00:35<00:48,  2.00it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████▏     | 68/164 [00:36<00:58,  1.63it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 69/164 [00:37<00:59,  1.58it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  43%|████▎     | 70/164 [00:37<00:50,  1.87it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  43%|████▎     | 71/164 [00:38<00:45,  2.05it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  44%|████▍     | 72/164 [00:38<00:39,  2.32it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  45%|████▍     | 73/164 [00:38<00:36,  2.50it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  45%|████▌     | 74/164 [00:38<00:29,  3.08it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  46%|████▌     | 75/164 [00:39<00:25,  3.44it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  46%|████▋     | 76/164 [00:39<00:22,  3.91it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  47%|████▋     | 77/164 [00:39<00:23,  3.75it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  48%|████▊     | 78/164 [00:39<00:22,  3.86it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  48%|████▊     | 79/164 [00:39<00:21,  3.93it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  49%|████▉     | 80/164 [00:40<00:21,  3.88it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  49%|████▉     | 81/164 [00:40<00:20,  4.12it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  50%|█████     | 82/164 [00:40<00:26,  3.08it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  51%|█████     | 83/164 [00:41<00:23,  3.43it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  51%|█████     | 84/164 [00:41<00:23,  3.41it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  52%|█████▏    | 85/164 [00:41<00:23,  3.41it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  52%|█████▏    | 86/164 [00:42<00:22,  3.47it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  53%|█████▎    | 87/164 [00:42<00:21,  3.57it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  54%|█████▎    | 88/164 [00:42<00:19,  3.87it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  54%|█████▍    | 89/164 [00:42<00:23,  3.22it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  55%|█████▍    | 90/164 [00:43<00:20,  3.64it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  55%|█████▌    | 91/164 [00:43<00:21,  3.34it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  56%|█████▌    | 92/164 [00:43<00:21,  3.37it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  57%|█████▋    | 93/164 [00:44<00:26,  2.71it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  57%|█████▋    | 94/164 [00:44<00:23,  2.95it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  58%|█████▊    | 95/164 [00:44<00:23,  2.90it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  59%|█████▊    | 96/164 [00:45<00:22,  3.07it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  59%|█████▉    | 97/164 [00:45<00:20,  3.24it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  60%|█████▉    | 98/164 [00:45<00:21,  3.06it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  60%|██████    | 99/164 [00:46<00:19,  3.31it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  61%|██████    | 100/164 [00:46<00:18,  3.54it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  62%|██████▏   | 101/164 [00:46<00:16,  3.72it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  62%|██████▏   | 102/164 [00:46<00:18,  3.41it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  63%|██████▎   | 103/164 [00:47<00:18,  3.26it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  63%|██████▎   | 104/164 [00:47<00:17,  3.40it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  64%|██████▍   | 105/164 [00:47<00:18,  3.12it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  65%|██████▍   | 106/164 [00:48<00:19,  3.02it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  65%|██████▌   | 107/164 [00:48<00:22,  2.51it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  66%|██████▌   | 108/164 [00:49<00:22,  2.47it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  66%|██████▋   | 109/164 [00:49<00:23,  2.39it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  67%|██████▋   | 110/164 [00:50<00:21,  2.50it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  68%|██████▊   | 111/164 [00:50<00:20,  2.53it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  68%|██████▊   | 112/164 [00:50<00:19,  2.68it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  69%|██████▉   | 113/164 [00:51<00:25,  2.02it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  70%|██████▉   | 114/164 [00:51<00:23,  2.09it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  70%|███████   | 115/164 [00:52<00:24,  1.98it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  71%|███████   | 116/164 [00:52<00:21,  2.22it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  71%|███████▏  | 117/164 [00:53<00:17,  2.63it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  72%|███████▏  | 118/164 [00:53<00:15,  2.94it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  73%|███████▎  | 119/164 [00:53<00:15,  2.94it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  73%|███████▎  | 120/164 [00:53<00:14,  2.96it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  74%|███████▍  | 121/164 [00:54<00:13,  3.14it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  74%|███████▍  | 122/164 [00:54<00:13,  3.08it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  75%|███████▌  | 123/164 [00:54<00:13,  3.09it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  76%|███████▌  | 124/164 [00:55<00:11,  3.35it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  76%|███████▌  | 125/164 [00:55<00:11,  3.46it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  77%|███████▋  | 126/164 [00:55<00:10,  3.73it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  77%|███████▋  | 127/164 [00:55<00:09,  3.73it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  78%|███████▊  | 128/164 [00:56<00:10,  3.48it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  79%|███████▊  | 129/164 [00:56<00:11,  3.03it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  79%|███████▉  | 130/164 [00:56<00:10,  3.11it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  80%|███████▉  | 131/164 [00:57<00:10,  3.18it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  80%|████████  | 132/164 [00:57<00:08,  3.66it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  81%|████████  | 133/164 [00:57<00:09,  3.40it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  82%|████████▏ | 134/164 [00:58<00:09,  3.12it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  82%|████████▏ | 135/164 [00:58<00:08,  3.38it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  83%|████████▎ | 136/164 [00:58<00:08,  3.46it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  84%|████████▎ | 137/164 [00:59<00:08,  3.11it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  84%|████████▍ | 138/164 [00:59<00:08,  2.93it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  85%|████████▍ | 139/164 [00:59<00:07,  3.19it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  85%|████████▌ | 140/164 [01:00<00:07,  3.34it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  86%|████████▌ | 141/164 [01:00<00:07,  3.22it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 142/164 [01:00<00:07,  3.12it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 143/164 [01:01<00:06,  3.05it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 144/164 [01:01<00:05,  3.37it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 145/164 [01:01<00:05,  3.26it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▉ | 146/164 [01:02<00:06,  2.83it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|████████▉ | 147/164 [01:02<00:06,  2.47it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|█████████ | 148/164 [01:02<00:05,  2.70it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 149/164 [01:03<00:06,  2.36it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████▏| 150/164 [01:03<00:06,  2.12it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 151/164 [01:04<00:05,  2.39it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 152/164 [01:04<00:04,  2.54it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 153/164 [01:05<00:04,  2.30it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▍| 154/164 [01:05<00:04,  2.07it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▍| 155/164 [01:05<00:03,  2.43it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▌| 156/164 [01:06<00:02,  2.70it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▌| 157/164 [01:06<00:02,  2.94it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▋| 158/164 [01:06<00:01,  3.00it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 159/164 [01:07<00:01,  2.75it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 160/164 [01:07<00:01,  2.84it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 161/164 [01:07<00:00,  3.07it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 162/164 [01:08<00:00,  2.59it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 163/164 [01:08<00:00,  2.79it/s][transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating: 100%|██████████| 164/164 [01:09<00:00,  2.38it/s]
#  Predictions saved : /content/drive/MyDrive/multilingual_health_qa/data/predictions_exp02_mt5small_lora_r16.csv
# ✓ Experiment log updated : /content/drive/MyDrive/multilingual_health_qa/data/experiment_log.json
# {
#   "config": {
#     "model": "google/mt5-small",
#     "lora": true,
#     "lora_r": 16,
#     "lora_alpha": 32,
#     "learning_rate": 0.0003,
#     "epochs": 3,
#     "batch_size": 8,
#     "prompt_version": "v1",
#     "purpose": "Fine-tuning effect vs zero-shot"
#   },
#   "metrics": {
#     "val_rouge1": 0.0034,
#     "val_rougeL": 0.0033,
#     "zindi_score": "pending"
#   }
# }
#  GPU memory freed
#   Used : 1.23 GB
#   Free : 14.21 GB
#
# ============================================================
# EXPERIMENT 2 COMPLETE
# ============================================================

# %%
# FIX — Define missing SUB_DIR variable
SUB_DIR = f'{BASE_DIR}/submissions'
import os
os.makedirs(SUB_DIR, exist_ok=True)
print(f"✓ SUB_DIR created: {SUB_DIR}")
# Out:
# ✓ SUB_DIR created: /content/drive/MyDrive/multilingual_health_qa/submissions

# %%
# FIX — Import files and download
from google.colab import files
files.download(sub_path2)

# %%
# Check what prompts were actually used
print(train['input_text'].iloc[0])
# Out:
# Language: Aka_Gha
# Question: Ɔkwan bɛn so na mmabunbɛtumi aboa wɔn mfɛfoɔ a nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ? Yei bi ne sɛnea wɔbɛkyekye wɔn werɛ, sɛnea wɔbɛboa wɔn ma wɔanya mmoa firi nnwumakuo a ɛfata hɔ, ne sɛnea wɔbɛsiw afɔbu suban ne nsɛm a nkurɔfoɔ de gu oyarefoɔ no so no kwan.
# Answer:

# %%
# EXPERIMENT 2 — Build submission and download
sub_path2 = build_submission(EXP2)
files.download(sub_path2)
print("\n NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 2: mt5-small LoRA r=16 fine-tuned'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")
# Out:
#  Submission saved  : /content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp02_mt5small_lora_r16.csv
#   Shape             : (2618, 4)
#   Columns           : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#
# First 3 rows:
#                        ID                   TargetRLF1                   TargetR1F1                    TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D     <extra_id_0> nkyerɛkyerɛ     <extra_id_0> nkyerɛkyerɛ     <extra_id_0> nkyerɛkyerɛ
# 1  ID_TS_Aka_Gha_1C80317F              <extra_id_0>?e蝾              <extra_id_0>?e蝾              <extra_id_0>?e蝾
# 2  ID_TS_Aka_Gha_06671AD1  <extra_id_0> bi mu ayɛ den?  <extra_id_0> bi mu ayɛ den?  <extra_id_0> bi mu ayɛ den?
#  NEXT STEPS:
# 1. Upload to Zindi → Comment: 'Exp 2: mt5-small LoRA r=16 fine-tuned'
# 2. Screenshot your score
# 3. Run the cell below with your real score

# %%
# EXPERIMENT 2 — Zindi score
ZINDI_SCORE_EXP2 = 0.004928

update_zindi_score(EXP2, ZINDI_SCORE_EXP2)
print(f"Exp 2 score recorded: {ZINDI_SCORE_EXP2}")
# Out:
# ✓ Zindi score updated: exp02_mt5small_lora_r16 = 0.004928
# Exp 2 score recorded: 0.004928

# %%
# EXPERIMENT 3 — flan-t5-base with LoRA r=16
# WHAT    : Switch backbone from mt5-small to flan-t5-base
# WHY     : Flan-T5 was instruction-tuned; it already understands
#           QA format. mt5 is pretrained only (no instruction
#           tuning), so flan-t5-base should outperform it even
#           with the same LoRA config. Model is the only variable.
# CHANGE  : Model: mt5-small → flan-t5-base

EXP3 = "exp03_flanT5base_lora_r16"

if not is_done(EXP3):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 3 : {EXP3}")
    print(f"Model        : google/flan-t5-base")
    print(f"LoRA         : r=16, alpha=32")
    print(f"LR / Epochs  : 3e-4 / 3")
    print(f"{'='*60}\n")

    tok3   = AutoTokenizer.from_pretrained("google/flan-t5-base")
    model3 = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
    print(f"Parameters : {model3.num_parameters():,}")

    lora3 = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=16, lora_alpha=32,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model3 = get_peft_model(model3, lora3)
    model3.print_trainable_parameters()

    train_tok3, val_tok3 = get_tokenized_datasets(
        tok3, train, val, max_input=256, max_target=256)

    trainer3 = run_training(
        model3, tok3, train_tok3, val_tok3,
        experiment_name=EXP3,
        learning_rate=3e-4, num_epochs=3,
        batch_size=8, max_target_len=256
    )

    save_model(model3, tok3, EXP3)
    plot_learning_curves(trainer3, EXP3)

    log3  = trainer3.state.log_history
    best3 = [x for x in log3 if 'eval_rouge1' in x]
    r1_3  = best3[-1]['eval_rouge1'] if best3 else 0.0
    rL_3  = best3[-1]['eval_rougeL'] if best3 else 0.0
    print(f"\n✓ Val ROUGE-1 : {r1_3:.4f}")
    print(f"✓ Val ROUGE-L : {rL_3:.4f}")

    print("\nRunning inference on test set...")
    answers3 = generate_answers(
        model3, tok3,
        test['input_text'].tolist(),
        batch_size=16, num_beams=4
    )
    save_predictions(test, answers3, EXP3)

    save_experiment_log(
        EXP3,
        config={
            "model": "google/flan-t5-base",
            "lora": True, "lora_r": 16, "lora_alpha": 32,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 8, "prompt_version": "v1",
            "purpose": "Instruction-tuned model vs mt5-small"
        },
        metrics={
            "val_rouge1": round(r1_3, 4),
            "val_rougeL": round(rL_3, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model3, tok3, trainer3)
    print(f"\n{'='*60}")
    print("EXPERIMENT 3 COMPLETE")
    print(f"{'='*60}")
else:
    print(f"✓ {EXP3} already done — skipping training")

# %%
# EXPERIMENT 3 — Build submission and download
sub_path3 = build_submission(EXP3)
files.download(sub_path3)
print("\n NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 3: flan-t5-base LoRA r=16'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")

# %%
# EXPERIMENT 3 — Paste your Zindi score here
ZINDI_SCORE_EXP3 = 0.0000  # ← replace with real score

update_zindi_score(EXP3, ZINDI_SCORE_EXP3)
print(f"Exp 3 score recorded: {ZINDI_SCORE_EXP3}")

# %%
# ══════════════════════════════════════════════════════════════
# EXPERIMENT 4 — flan-t5-base with LoRA r=32
# WHAT    : Double the LoRA rank from 16 to 32
# WHY     : Higher rank = more trainable parameters = more
#           capacity to adapt to the task. Tests whether
#           the extra capacity helps or overfits on this
#           relatively small multilingual dataset.
#           Only rank changes vs Exp 3 — controlled comparison.
# CHANGE  : LoRA r=16 → r=32, alpha=32 → alpha=64
# ══════════════════════════════════════════════════════════════

EXP4 = "exp04_flanT5base_lora_r32"

if not is_done(EXP4):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 4 : {EXP4}")
    print(f"Model        : google/flan-t5-base")
    print(f"LoRA         : r=32, alpha=64  ← doubled from Exp 3")
    print(f"LR / Epochs  : 3e-4 / 3")
    print(f"{'='*60}\n")

    tok4   = AutoTokenizer.from_pretrained("google/flan-t5-base")
    model4 = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

    lora4 = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=32, lora_alpha=64,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model4 = get_peft_model(model4, lora4)
    model4.print_trainable_parameters()

    train_tok4, val_tok4 = get_tokenized_datasets(
        tok4, train, val, max_input=256, max_target=256)

    trainer4 = run_training(
        model4, tok4, train_tok4, val_tok4,
        experiment_name=EXP4,
        learning_rate=3e-4, num_epochs=3,
        batch_size=8, max_target_len=256
    )

    save_model(model4, tok4, EXP4)
    plot_learning_curves(trainer4, EXP4)

    log4  = trainer4.state.log_history
    best4 = [x for x in log4 if 'eval_rouge1' in x]
    r1_4  = best4[-1]['eval_rouge1'] if best4 else 0.0
    rL_4  = best4[-1]['eval_rougeL'] if best4 else 0.0
    print(f"\n✓ Val ROUGE-1 : {r1_4:.4f}")
    print(f"✓ Val ROUGE-L : {rL_4:.4f}")

    print("\nRunning inference on test set...")
    answers4 = generate_answers(
        model4, tok4,
        test['input_text'].tolist(),
        batch_size=16, num_beams=4
    )
    save_predictions(test, answers4, EXP4)

    save_experiment_log(
        EXP4,
        config={
            "model": "google/flan-t5-base",
            "lora": True, "lora_r": 32, "lora_alpha": 64,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 8, "prompt_version": "v1",
            "purpose": "Higher LoRA rank — capacity vs overfitting tradeoff"
        },
        metrics={
            "val_rouge1": round(r1_4, 4),
            "val_rougeL": round(rL_4, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model4, tok4, trainer4)
    print(f"\n{'='*60}")
    print("EXPERIMENT 4 COMPLETE")
    print(f"{'='*60}")
else:
    print(f"✓ {EXP4} already done — skipping training")

# %%
# EXPERIMENT 4 — Build submission and download
sub_path4 = build_submission(EXP4)
files.download(sub_path4)
print("\n📋 NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 4: flan-t5-base LoRA r=32'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")

# %%
# EXPERIMENT 4 — Paste your Zindi score here
ZINDI_SCORE_EXP4 = 0.0000  # ← replace with real score

update_zindi_score(EXP4, ZINDI_SCORE_EXP4)
print(f"Exp 4 score recorded: {ZINDI_SCORE_EXP4}")

# %%
# ══════════════════════════════════════════════════════════════
# EXPERIMENT 5 — flan-t5-base with Improved Prompt v2
# WHAT    : Add explicit health assistant role to the prompt
# WHY     : Flan-T5 was instruction-tuned so it responds better
#           to role-based prompts. A health-framed instruction
#           may steer the model toward more medically relevant
#           and language-appropriate answers.
#           Same model + LoRA as Exp 3 — only prompt changes.
# CHANGE  : Prompt v1 → v2
#   v1: "Language: {l}\nQuestion: {q}\nAnswer:"
#   v2: "You are a health assistant. Answer the following
#        health question in {l}.\nQuestion: {q}\nAnswer:"
# ══════════════════════════════════════════════════════════════

EXP5 = "exp05_flanT5base_promptv2"

if not is_done(EXP5):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 5 : {EXP5}")
    print(f"Model        : google/flan-t5-base")
    print(f"LoRA         : r=16, alpha=32")
    print(f"CHANGE       : Prompt v1 → v2 (health assistant role)")
    print(f"{'='*60}\n")

    # Build v2 prompts
    def build_v2(q, l):
        return (f"You are a health assistant. Answer the following "
                f"health question in {l}.\nQuestion: {q}\nAnswer:")

    train5 = train.copy()
    val5   = val.copy()
    test5  = test.copy()
    train5['input_text'] = train5.apply(lambda r: build_v2(r[q_col], r[lang_col]), axis=1)
    val5['input_text']   = val5.apply(  lambda r: build_v2(r[q_col], r[lang_col]), axis=1)
    test5['input_text']  = test5.apply( lambda r: build_v2(r[q_col], r[lang_col]), axis=1)

    print("Sample v2 prompt:")
    print(train5['input_text'].iloc[0])
    print()

    tok5   = AutoTokenizer.from_pretrained("google/flan-t5-base")
    model5 = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

    lora5 = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=16, lora_alpha=32,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model5 = get_peft_model(model5, lora5)
    model5.print_trainable_parameters()

    train_tok5, val_tok5 = get_tokenized_datasets(
        tok5, train5, val5, max_input=256, max_target=256)

    trainer5 = run_training(
        model5, tok5, train_tok5, val_tok5,
        experiment_name=EXP5,
        learning_rate=3e-4, num_epochs=3,
        batch_size=8, max_target_len=256
    )

    save_model(model5, tok5, EXP5)
    plot_learning_curves(trainer5, EXP5)

    log5  = trainer5.state.log_history
    best5 = [x for x in log5 if 'eval_rouge1' in x]
    r1_5  = best5[-1]['eval_rouge1'] if best5 else 0.0
    rL_5  = best5[-1]['eval_rougeL'] if best5 else 0.0
    print(f"\n✓ Val ROUGE-1 : {r1_5:.4f}")
    print(f"✓ Val ROUGE-L : {rL_5:.4f}")

    print("\nRunning inference on test set...")
    answers5 = generate_answers(
        model5, tok5,
        test5['input_text'].tolist(),
        batch_size=16, num_beams=4
    )
    save_predictions(test, answers5, EXP5)

    save_experiment_log(
        EXP5,
        config={
            "model": "google/flan-t5-base",
            "lora": True, "lora_r": 16, "lora_alpha": 32,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 8, "prompt_version": "v2",
            "purpose": "Prompt engineering — health assistant role instruction"
        },
        metrics={
            "val_rouge1": round(r1_5, 4),
            "val_rougeL": round(rL_5, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model5, tok5, trainer5)
    print(f"\n{'='*60}")
    print("EXPERIMENT 5 COMPLETE")
    print(f"{'='*60}")
else:
    print(f"✓ {EXP5} already done — skipping training")

# %%
# EXPERIMENT 5 — Build submission and download
sub_path5 = build_submission(EXP5)
files.download(sub_path5)
print("\n📋 NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 5: flan-t5-base prompt v2 health role'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")

# %%
# EXPERIMENT 5 — Paste your Zindi score here
ZINDI_SCORE_EXP5 = 0.0000  # ← replace with real score

update_zindi_score(EXP5, ZINDI_SCORE_EXP5)
print(f"Exp 5 score recorded: {ZINDI_SCORE_EXP5}")

# %%
# ══════════════════════════════════════════════════════════════
# EXPERIMENT 6 — flan-t5-large with LoRA r=16
# WHAT    : Scale backbone to flan-t5-large (3× bigger than base)
# WHY     : Larger models have more language understanding.
#           Tests whether model scale alone improves multilingual
#           health QA beyond what prompt/LoRA tuning achieved.
#           Uses float16 + smaller batch to fit T4 GPU memory.
# CHANGE  : flan-t5-base → flan-t5-large, batch_size 8 → 4
# NOTE    : Takes ~60–90 min on T4. Do NOT interrupt mid-training.
# ══════════════════════════════════════════════════════════════

EXP6 = "exp06_flanT5large_lora_r16"

if not is_done(EXP6):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 6 : {EXP6}")
    print(f"Model        : google/flan-t5-large")
    print(f"LoRA         : r=16, alpha=32")
    print(f"Batch        : 4  (reduced to fit GPU memory)")
    print(f"NOTE         : Takes ~60–90 min on T4 GPU")
    print(f"{'='*60}\n")

    # Safety check: GPU memory
    if torch.cuda.is_available():
        free_mem = torch.cuda.mem_get_info()[0] / 1e9
        print(f"Available GPU memory: {free_mem:.1f} GB")
        if free_mem < 4.0:
            print("⚠ WARNING: Low GPU memory detected!")
            print("  → Go to Runtime → Disconnect and delete runtime")
            print("  → Reconnect and re-run S0 → S7 before running Exp 6")
            raise RuntimeError("Insufficient GPU memory — please reconnect runtime first")

    tok6   = AutoTokenizer.from_pretrained("google/flan-t5-large")
    model6 = AutoModelForSeq2SeqLM.from_pretrained(
        "google/flan-t5-large",
        torch_dtype=torch.float16   # saves ~50% GPU memory vs float32
    )
    print(f"Parameters : {model6.num_parameters():,}")

    lora6 = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=16, lora_alpha=32,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model6 = get_peft_model(model6, lora6)
    model6.print_trainable_parameters()

    train_tok6, val_tok6 = get_tokenized_datasets(
        tok6, train, val, max_input=256, max_target=256)

    trainer6 = run_training(
        model6, tok6, train_tok6, val_tok6,
        experiment_name=EXP6,
        learning_rate=3e-4, num_epochs=3,
        batch_size=4,           # smaller batch for large model
        max_target_len=256
    )

    save_model(model6, tok6, EXP6)
    plot_learning_curves(trainer6, EXP6)

    log6  = trainer6.state.log_history
    best6 = [x for x in log6 if 'eval_rouge1' in x]
    r1_6  = best6[-1]['eval_rouge1'] if best6 else 0.0
    rL_6  = best6[-1]['eval_rougeL'] if best6 else 0.0
    print(f"\n✓ Val ROUGE-1 : {r1_6:.4f}")
    print(f"✓ Val ROUGE-L : {rL_6:.4f}")

    print("\nRunning inference on test set...")
    answers6 = generate_answers(
        model6, tok6,
        test['input_text'].tolist(),
        batch_size=8, num_beams=4
    )
    save_predictions(test, answers6, EXP6)

    save_experiment_log(
        EXP6,
        config={
            "model": "google/flan-t5-large",
            "lora": True, "lora_r": 16, "lora_alpha": 32,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 4, "prompt_version": "v1",
            "note": "float16 loading to fit T4 GPU memory",
            "purpose": "Model scale effect — large vs base"
        },
        metrics={
            "val_rouge1": round(r1_6, 4),
            "val_rougeL": round(rL_6, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model6, tok6, trainer6)
    print(f"\n{'='*60}")
    print("EXPERIMENT 6 COMPLETE")
    print(f"{'='*60}")
else:
    print(f"✓ {EXP6} already done — skipping training")

# %%
# EXPERIMENT 6 — Build submission and download
sub_path6 = build_submission(EXP6)
files.download(sub_path6)
print("\n📋 NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 6: flan-t5-large LoRA r=16 — FINAL BEST'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")

# %%
# EXPERIMENT 6 — Paste your Zindi score here
ZINDI_SCORE_EXP6 = 0.0000  # ← replace with real score

update_zindi_score(EXP6, ZINDI_SCORE_EXP6)
print(f"Exp 6 score recorded: {ZINDI_SCORE_EXP6}")
print("\n🎉 All 6 experiments complete!")
