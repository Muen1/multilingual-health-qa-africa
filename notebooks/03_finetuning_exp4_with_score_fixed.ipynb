# %% [markdown]
# <a href="https://colab.research.google.com/github/Muen1/multilingual-health-qa-africa/blob/main/notebooks/03_finetuning_exp4_with_score_fixed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Fix before GitHub commit — run this LAST before committing
import json, glob

for nb_path in glob.glob('/content/**/*.ipynb', recursive=True):
    with open(nb_path) as f:
        nb = json.load(f)
    if 'widgets' in nb.get('metadata', {}):
        del nb['metadata']['widgets']
        with open(nb_path, 'w') as f:
            json.dump(nb, f, indent=1)
        print(f" Fixed: {nb_path}")
# Out:
#  Fixed: /content/drive/MyDrive/Colab Notebooks/03_finetuning_exp4 (1).ipynb

# %%
# CELL 0 — Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
import os

BASE_DIR = '/content/drive/MyDrive/multilingual_health_qa'
DATA_DIR = f'{BASE_DIR}/data'
OUT_DIR  = f'{BASE_DIR}/outputs'
PLOT_DIR = f'{BASE_DIR}/plots'
SUB_DIR  = f'{BASE_DIR}/submissions'

for d in [OUT_DIR, PLOT_DIR]:
    os.makedirs(d, exist_ok=True)

print("Drive mounted.")
print("Data files:", os.listdir(DATA_DIR))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted.
# Data files: ['Train.csv', 'Val.csv', 'Test.csv', 'SampleSubmission.csv', 'train_clean.csv', 'val_clean.csv', 'test_clean.csv', 'predictions_exp01_mt5small_zeroshot.csv', 'predictions_exp02_mt5small_lora_r16.csv', 'predictions_exp04_flanT5base_lora_r32.csv', 'predictions_exp05_flanT5base_promptv2.csv', 'predictions_exp03_flanT5base_lora_r16.csv', 'predictions_exp06_flanT5large_lora_r16.csv', 'experiment_log.json']

# %%
# ===== EXPERIMENT 4 CONFIGURATION =====
# Notebook: 03_finetuning_exp4_with_score_fixed.ipynb
# GitHub  : https://github.com/Muen1/multilingual-health-qa-africa

EXP_NAME   = "exp04_flanT5base_lora_r32"
MODEL_NAME = "google/flan-t5-base"
LORA_R     = 32
LORA_ALPHA = 64
LR         = 3e-4
EPOCHS     = 3
BATCH_SIZE = 4
MAX_INPUT  = 128
MAX_TARGET = 64
PROMPT_VER = "v1"

# WHY THIS EXPERIMENT:
# Experiment 3 (flan-t5-base, r=16) gave a strong improvement.
# We hypothesize that doubling the LoRA rank from r=16 to r=32
# gives the model more trainable parameters (capacity) to adapt
# to the multilingual health question-answering task.
# TRADEOFF: more parameters → slower training + risk of overfitting
#           on this relatively small dataset.
# Everything else stays identical to Exp 3 for a controlled
# comparison — only the LoRA rank changes.
# KEY CHANGE: LoRA r=16, alpha=32 → r=32, alpha=64

print(f"Experiment : {EXP_NAME}")
print(f"Model      : {MODEL_NAME}")
print(f"LoRA rank  : r={LORA_R}, alpha={LORA_ALPHA}  ← doubled from Exp 3")
print(f"LR/Epochs  : {LR} / {EPOCHS}")
print(f"Prompt     : {PROMPT_VER}")

# %%
# CELL S2 — Install only what's missing (compatible with Colab's pre-installed versions)
# !pip install -q evaluate rouge-score sentencepiece

# Verify
import importlib
packages = ['transformers', 'datasets', 'peft', 'accelerate', 'evaluate', 'rouge_score', 'sentencepiece']
print("\n=== Installed versions ===")
for p in packages:
    try:
        mod = importlib.import_module(p)
        ver = getattr(mod, '__version__', 'installed')
        print(f"  ✓ {p}: {ver}")
    except:
        print(f"  ✗ {p}: MISSING")

print("\nInstallation complete — no restart needed.")
# Out:
# === Installed versions ===
#   ✓ transformers: 5.10.2
#   ✓ datasets: 4.0.0
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
#   ✓ peft: 0.19.1
#   ✓ accelerate: 1.13.0
#   ✓ evaluate: 0.4.6
#   ✓ rouge_score: installed
#   ✓ sentencepiece: 0.2.1
#
# Installation complete — no restart needed.

# %%
# CELL S3 — Package check
import importlib, sys

required = {
    'transformers': '4.0',
    'datasets': '2.0',
    'peft': '0.5',
    'accelerate': '0.20',
    'evaluate': '0.4',
    'rouge_score': '0.1',
    'sentencepiece': '0.1',
}

print("=== Package check ===")
all_ok = True
for pkg, min_ver in required.items():
    try:
        mod = importlib.import_module(pkg)
        ver = getattr(mod, '__version__', '?')
        print(f"  ✓ {pkg}: {ver}")
    except ImportError:
        print(f"  ✗ {pkg}: MISSING")
        all_ok = False

if all_ok:
    print("\n✓ All packages present — ready to continue.")
else:
    print("\n✗ Run: !pip install -q evaluate rouge-score sentencepiece")
# Out:
# === Package check ===
#   ✓ transformers: 5.10.2
#   ✓ datasets: 4.0.0
#   ✓ peft: 0.19.1
#   ✓ accelerate: 1.13.0
#   ✓ evaluate: 0.4.6
#   ✓ rouge_score: ?
#   ✓ sentencepiece: 0.2.1
#
# ✓ All packages present — ready to continue.

# %%
# imports
import gc
import os
import json
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import evaluate as hf_evaluate
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq,
    EarlyStoppingCallback
)
from peft import get_peft_model, LoraConfig, TaskType
from datasets import Dataset

print("PyTorch version :", torch.__version__)
print("CUDA available  :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU             :", torch.cuda.get_device_name(0))
else:
    print("WARNING: No GPU detected. Go to Runtime → Change runtime type → T4 GPU")
# Out:
# PyTorch version : 2.11.0+cpu
# CUDA available  : False
# WARNING: No GPU detected. Go to Runtime → Change runtime type → T4 GPU

# %%
# CELL S4 — Load cleaned data
train = pd.read_csv(f'{DATA_DIR}/train_clean.csv')
val   = pd.read_csv(f'{DATA_DIR}/val_clean.csv')
test  = pd.read_csv(f'{DATA_DIR}/test_clean.csv')

# Column mapping for this dataset
q_col    = 'input'
a_col    = 'output'
lang_col = 'subset'
id_col   = 'ID'

# Rebuild prompts v1 if missing
if 'input_text' not in train.columns:
    def _prompt_v1(q, l):
        return f"Language: {l}\nQuestion: {q}\nAnswer:"
    train['input_text']  = train.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)
    train['target_text'] = train[a_col].astype(str)
    val['input_text']    = val.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)
    val['target_text']   = val[a_col].astype(str)
    test['input_text']   = test.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)

print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")
print("Sample input:", train['input_text'].iloc[0])
print("Sample target:", train['target_text'].iloc[0][:150])
# Out:
# Train: 29814, Val: 6686, Test: 2618
# Sample input: Language: Aka_Gha
# Question: Ɔkwan bɛn so na mmabunbɛtumi aboa wɔn mfɛfoɔ a nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ? Yei bi ne sɛnea wɔbɛkyekye wɔn werɛ, sɛnea wɔbɛboa wɔn ma wɔanya mmoa firi nnwumakuo a ɛfata hɔ, ne sɛnea wɔbɛsiw afɔbu suban ne nsɛm a nkurɔfoɔ de gu oyarefoɔ no so no kwan.
# Answer:
# Sample target: Mmabun betumi aboa atipɛnfo a ebia nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ so denam: Nkate fam mmoa a wɔde bɛma na wɔagye wɔn nkate atom a wɔremmu atɛ

# %%
# CELL S5 — Load sample submission and verify format
sample = pd.read_csv(f'{DATA_DIR}/SampleSubmission.csv')
print(" Sample submission loaded")
print(f"  Columns : {sample.columns.tolist()}")
print(f"  Shape   : {sample.shape}")
print(f"\nFirst 2 rows:")
print(sample.head(2).to_string())
# Out:
#  Sample submission loaded
#   Columns : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#   Shape   : (2618, 4)
#
# First 2 rows:
#                        ID             TargetRLF1             TargetR1F1              TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  Wuna dey craze, eweeh  Wuna dey craze, eweeh  Wuna dey craze, eweeh
# 1  ID_TS_Aka_Gha_1C80317F  Wuna dey craze, eweeh  Wuna dey craze, eweeh  Wuna dey craze, eweeh

# %%
# FIX — Upgrade torchao to fix peft compatibility
# RUN ONCE AND NEVER AGAIN
# !pip install -q --upgrade torchao

# Restart runtime after this installs
import os
os.kill(os.getpid(), 9)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 9.3 MB/s eta 0:00:00

# %%
# Confirm torchao version is correct
import torchao
import peft
import torch

print(f"torchao : {torchao.__version__}")
print(f"peft    : {peft.__version__}")
print(f"torch   : {torch.__version__}")
print(f"GPU     : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NOT AVAILABLE'}")

# Quick test that get_peft_model works without the ImportError
from peft import LoraConfig, TaskType, get_peft_model
from transformers import AutoModelForSeq2SeqLM

print("\nTesting peft import...")
test_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
test_lora  = LoraConfig(task_type=TaskType.SEQ_2_SEQ_LM, r=8, lora_alpha=16,
                         target_modules=["q", "v"], bias="none")
test_model = get_peft_model(test_model, test_lora)
print("✓ get_peft_model works correctly")
print("✓ Ready to run experiments")

del test_model
# Out:
# torchao : 0.17.0
# peft    : 0.19.1
# torch   : 2.11.0+cpu
# GPU     : NOT AVAILABLE
#
# Testing peft import...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ✓ get_peft_model works correctly
# ✓ Ready to run experiments

# %%
# CELL S6 — All shared helper functions

#  1. ROUGE metric
rouge_metric = hf_evaluate.load("rouge")

#  2. Tokenize datasets
def get_tokenized_datasets(tokenizer, train_df, val_df,
                            max_input=128, max_target=64):
    def preprocess(examples):
        inputs = tokenizer(
            examples['input_text'],
            max_length=max_input,
            truncation=True,
            padding='max_length'
        )
        targets = tokenizer(
            examples['target_text'],
            max_length=max_target,
            truncation=True,
            padding='max_length'
        )
        labels = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label]
            for label in targets['input_ids']
        ]
        inputs['labels'] = labels
        return inputs

    train_ds  = Dataset.from_pandas(
        train_df[['input_text','target_text']].reset_index(drop=True))
    val_ds    = Dataset.from_pandas(
        val_df[['input_text','target_text']].reset_index(drop=True))
    train_tok = train_ds.map(preprocess, batched=True,
                             remove_columns=['input_text','target_text'])
    val_tok   = val_ds.map(preprocess,   batched=True,
                           remove_columns=['input_text','target_text'])
    return train_tok, val_tok

# 3. Compute metrics
def make_compute_metrics(tokenizer):
    def compute_metrics(eval_preds):
        preds, labels = eval_preds
        if isinstance(preds, tuple):
            preds = preds[0]

        preds  = np.where(preds  != -100, preds,  tokenizer.pad_token_id)
        labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
        preds  = np.clip(preds, 0, tokenizer.vocab_size - 1)

        decoded_preds  = tokenizer.batch_decode(
            preds,  skip_special_tokens=True)
        decoded_labels = tokenizer.batch_decode(
            labels, skip_special_tokens=True)
        decoded_preds  = [p.strip() for p in decoded_preds]
        decoded_labels = [l.strip() for l in decoded_labels]
        result = rouge_metric.compute(
            predictions=decoded_preds,
            references=decoded_labels,
            use_stemmer=True
        )
        return {
            "rouge1": round(result["rouge1"], 4),
            "rougeL": round(result["rougeL"], 4)
        }
    return compute_metrics

# 4. Training
def run_training(model, tokenizer, train_tok, val_tok,
                 experiment_name, learning_rate,
                 num_epochs, batch_size, max_target_len):
    args = Seq2SeqTrainingArguments(
        output_dir=f"{OUT_DIR}/checkpoints_{experiment_name}",
        num_train_epochs=num_epochs,
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=50,
        learning_rate=learning_rate,
        weight_decay=0.01,
        fp16=True,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="eval_loss",
        predict_with_generate=True,
        generation_max_length=64,
        logging_steps=50,
        report_to="none",
        push_to_hub=False
    )
    collator = DataCollatorForSeq2Seq(tokenizer, model=model, padding=True)
    trainer  = Seq2SeqTrainer(
        model=model,
        args=args,
        train_dataset=train_tok,
        eval_dataset=val_tok,
        processing_class=tokenizer,
        data_collator=collator,
        compute_metrics=make_compute_metrics(tokenizer),
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
    )
    est = len(train_tok) * num_epochs / (4 * 4) / 60
    print(f" Estimated time : ~{est:.0f} minutes")
    print("Starting training...")
    trainer.train()
    return trainer

# 5. Save model
def save_model(model, tokenizer, experiment_name):
    path = f'{OUT_DIR}/model_{experiment_name}'
    os.makedirs(path, exist_ok=True)
    model.save_pretrained(path)
    tokenizer.save_pretrained(path)
    print(f" Model saved : {path}")
    return path

# 6. Generate answers
def generate_answers(model, tokenizer, texts,
                     max_input=128, max_target=64,
                     batch_size=8, num_beams=4):
    model.eval()
    if torch.cuda.is_available():
        model = model.cuda()
    all_answers = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Generating"):
        batch  = texts[i:i+batch_size]
        inputs = tokenizer(
            batch, return_tensors='pt',
            max_length=max_input,
            truncation=True, padding=True
        )
        if torch.cuda.is_available():
            inputs = {k: v.cuda() for k, v in inputs.items()}
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_target,
                num_beams=num_beams,
                no_repeat_ngram_size=3,
                length_penalty=1.0
            )
        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        all_answers.extend(decoded)
    return all_answers

# 7. Save predictions
def save_predictions(test_df, answers, experiment_name):
    out              = test_df.copy()
    out['predicted_answer'] = answers
    path             = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    out.to_csv(path, index=False)
    print(f" Predictions saved : {path}")
    return path

# 8. Build Zindi submission
def build_submission(experiment_name):
    pred_path = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    if not os.path.exists(pred_path):
        print(f"✗ No predictions found for {experiment_name}")
        print(f"  Expected at: {pred_path}")
        return None

    preds       = pd.read_csv(pred_path)
    pred_id_col = preds.columns[0]
    pred_answer = preds['predicted_answer'].astype(str).values

    submission  = pd.DataFrame({
        'ID':         preds[pred_id_col].values,
        'TargetRLF1': pred_answer,
        'TargetR1F1': pred_answer,
        'TargetLLM':  pred_answer
    })

    assert list(submission.columns) == ['ID','TargetRLF1','TargetR1F1','TargetLLM'], \
        "Column mismatch!"
    assert len(submission) == len(sample), \
        f"Row mismatch: {len(submission)} vs {len(sample)}"
    assert submission.isnull().sum().sum() == 0, \
        "Null values found!"

    path = f'{SUB_DIR}/submission_{experiment_name}.csv'
    submission.to_csv(path, index=False)
    print(f" Submission saved  : {path}")
    print(f"  Shape             : {submission.shape}")
    print(f"  Columns           : {submission.columns.tolist()}")
    print(f"\nFirst 3 rows:")
    print(submission.head(3).to_string())
    return path

# 9. Plot learning curves
def plot_learning_curves(trainer, experiment_name):
    log      = trainer.state.log_history
    t_steps  = [x['step']      for x in log
                if 'loss' in x and 'eval_loss' not in x]
    t_losses = [x['loss']      for x in log
                if 'loss' in x and 'eval_loss' not in x]
    e_epochs = [x['epoch']     for x in log if 'eval_loss' in x]
    e_losses = [x['eval_loss'] for x in log if 'eval_loss' in x]
    e_r1     = [x.get('eval_rouge1', 0) for x in log if 'eval_loss' in x]
    e_rL     = [x.get('eval_rougeL', 0) for x in log if 'eval_loss' in x]

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(f'Learning Curves — {experiment_name}',
                 fontsize=13, fontweight='bold')

    axes[0].plot(t_steps, t_losses, color='royalblue', linewidth=1.5)
    axes[0].set_title('Training Loss')
    axes[0].set_xlabel('Step')
    axes[0].set_ylabel('Loss')
    axes[0].grid(True, alpha=0.4)

    axes[1].plot(e_epochs, e_losses, color='darkorange',
                 marker='o', linewidth=2)
    axes[1].set_title('Validation Loss per Epoch')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Eval Loss')
    axes[1].grid(True, alpha=0.4)

    axes[2].plot(e_epochs, e_r1, color='green',
                 marker='o', linewidth=2, label='ROUGE-1')
    axes[2].plot(e_epochs, e_rL, color='purple',
                 marker='s', linewidth=2, label='ROUGE-L')
    axes[2].set_title('ROUGE Scores per Epoch')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('F1 Score')
    axes[2].legend()
    axes[2].grid(True, alpha=0.4)

    plt.tight_layout()
    path = f'{PLOT_DIR}/learning_curves_{experiment_name}.png'
    plt.savefig(path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"✓ Learning curves saved : {path}")

#  10. Experiment log
LOG_PATH = f'{DATA_DIR}/experiment_log.json'

def save_experiment_log(experiment_name, config, metrics):
    log = {}
    if os.path.exists(LOG_PATH):
        with open(LOG_PATH, 'r') as f:
            log = json.load(f)
    log[experiment_name] = {"config": config, "metrics": metrics}
    with open(LOG_PATH, 'w') as f:
        json.dump(log, f, indent=2)
    print(f"✓ Experiment log updated : {LOG_PATH}")
    print(json.dumps(log[experiment_name], indent=2))

def update_zindi_score(experiment_name, score):
    if not os.path.exists(LOG_PATH):
        print("No log file found. Run the experiment first.")
        return
    with open(LOG_PATH, 'r') as f:
        log = json.load(f)
    if experiment_name not in log:
        print(f"Experiment {experiment_name} not in log.")
        return
    log[experiment_name]['metrics']['zindi_score'] = score
    with open(LOG_PATH, 'w') as f:
        json.dump(log, f, indent=2)
    print(f"✓ Zindi score updated: {experiment_name} = {score}")

# 11. Check if already done
def is_done(experiment_name):
    pred_path = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    if os.path.exists(pred_path):
        print(f"✓ ALREADY DONE: {experiment_name}")
        print(f"  Predictions at: {pred_path}")
        print("  Skipping to submission cell.")
        return True
    print(f" NOT YET DONE: {experiment_name} — will run now.")
    return False

# 12. Free GPU memory
def free_gpu(*objects):
    for obj in objects:
        del obj
    gc.collect()
    torch.cuda.empty_cache()
    if torch.cuda.is_available():
        used = torch.cuda.memory_allocated() / 1e9
        free = torch.cuda.mem_get_info()[0] / 1e9
        print(f" GPU memory freed")
        print(f"  Used : {used:.2f} GB")
        print(f"  Free : {free:.2f} GB")

print("✓ All helper functions loaded and ready.")
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# ✓ All helper functions loaded and ready.

# %%
# CELL S7 — Check what experiments are already done
import os, json

print("=== EXPERIMENT STATUS ===\n")

experiments_list = [
    "exp01_mt5small_zeroshot",
    "exp02_mt5small_lora_r16",
    "exp03_flanT5base_lora_r16",
    "exp04_flanT5base_lora_r32",
    "exp05_flanT5base_promptv2",
    "exp06_flanT5large_lora_r16"
]

for exp in experiments_list:
    pred_path = f'{DATA_DIR}/predictions_{exp}.csv'
    sub_path  = f'{DATA_DIR}/../submissions/submission_{exp}.csv'
    done      = "✓ DONE" if os.path.exists(pred_path) else "✗ NOT DONE"
    submitted = "✓ SUBMITTED" if os.path.exists(sub_path) else "✗ NOT SUBMITTED"
    print(f"{exp}")
    print(f"  Predictions : {done}")
    print(f"  Submission  : {submitted}")
    print()

if os.path.exists(LOG_PATH):
    print("=== SCORES SO FAR ===")
    with open(LOG_PATH, 'r') as f:
        log = json.load(f)
    for name, entry in log.items():
        m = entry.get('metrics', {})
        print(f"  {name}")
        print(f"    ROUGE-1    : {m.get('val_rouge1', 'N/A')}")
        print(f"    ROUGE-L    : {m.get('val_rougeL', 'N/A')}")
        print(f"    Zindi Score: {m.get('zindi_score', 'not yet')}")
        print()
else:
    print("No experiment log yet — starting fresh.")
# Out:
# === EXPERIMENT STATUS ===
#
# exp01_mt5small_zeroshot
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp02_mt5small_lora_r16
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp03_flanT5base_lora_r16
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp04_flanT5base_lora_r32
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp05_flanT5base_promptv2
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp06_flanT5large_lora_r16
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# === SCORES SO FAR ===
#   exp02_mt5small_lora_r16
#     ROUGE-1    : 0.0034
#     ROUGE-L    : 0.0033
#     Zindi Score: 0.00167
#
#   exp04_flanT5base_lora_r32
#     ROUGE-1    : 0.1057
#     ROUGE-L    : 0.091
#     Zindi Score: 0.152634
#
#   exp05_flanT5base_promptv2
#     ROUGE-1    : 0.0773
#     ROUGE-L    : 0.069
#     Zindi Score: 0.141087
#
#   exp03_flanT5base_lora_r16
#     ROUGE-1    : 0.1056
#     ROUGE-L    : 0.091
#     Zindi Score: 0.155076
#
#   exp06_flanT5large_lora_r16
#     ROUGE-1    : 0.0777
#     ROUGE-L    : 0.0696
#     Zindi Score: 0.149083

# %%
# ══════════════════════════════════════════════════════════════
# EXPERIMENT 4 — flan-t5-base with LoRA r=32
# WHAT    : Double the LoRA rank from 16 to 32
# WHY     : Higher rank = more trainable parameters = more
#           capacity to adapt to the task. Tests whether
#           the extra capacity helps or overfits on this
#           relatively small multilingual dataset.
#           Only rank changes vs Exp 3 — controlled comparison.
# CHANGE  : LoRA r=16 → r=32, alpha=32 → alpha=64
# ══════════════════════════════════════════════════════════════

# Free GPU memory before starting
import gc, torch
gc.collect()
torch.cuda.empty_cache()
print(f"Free GPU memory: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB")

EXP4 = "exp04_flanT5base_lora_r32"

if not is_done(EXP4):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 4 : {EXP4}")
    print(f"Model        : google/flan-t5-base")
    print(f"LoRA         : r=32, alpha=64  ← doubled from Exp 3")
    print(f"LR / Epochs  : 3e-4 / 3")
    print(f"{'='*60}\n")

    tok4   = AutoTokenizer.from_pretrained("google/flan-t5-base")
    model4 = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

    lora4 = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=32, lora_alpha=64,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model4 = get_peft_model(model4, lora4)
    model4.print_trainable_parameters()

    train_tok4, val_tok4 = get_tokenized_datasets(
        tok4, train, val,
        max_input=128, max_target=64)        # ← CHANGED: was 256/256

    trainer4 = run_training(
        model4, tok4, train_tok4, val_tok4,
        experiment_name=EXP4,
        learning_rate=3e-4, num_epochs=3,
        batch_size=4, max_target_len=64      # ← CHANGED: batch 8→4, target 256→64
    )

    save_model(model4, tok4, EXP4)
    plot_learning_curves(trainer4, EXP4)

    log4  = trainer4.state.log_history
    best4 = [x for x in log4 if 'eval_rouge1' in x]
    r1_4  = best4[-1]['eval_rouge1'] if best4 else 0.0
    rL_4  = best4[-1]['eval_rougeL'] if best4 else 0.0
    print(f"\n✓ Val ROUGE-1 : {r1_4:.4f}")
    print(f"✓ Val ROUGE-L : {rL_4:.4f}")

    print("\nRunning inference on test set...")
    answers4 = generate_answers(
        model4, tok4,
        test['input_text'].tolist(),
        batch_size=8, num_beams=4            # ← CHANGED: was 16
    )
    save_predictions(test, answers4, EXP4)

    save_experiment_log(
        EXP4,
        config={
            "model": "google/flan-t5-base",
            "lora": True, "lora_r": 32, "lora_alpha": 64,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 4,                 # ← CHANGED: was 8
            "max_input": 128,                # ← CHANGED: added
            "max_target": 64,                # ← CHANGED: added
            "prompt_version": "v1",
            "purpose": "Higher LoRA rank — capacity vs overfitting tradeoff"
        },
        metrics={
            "val_rouge1": round(r1_4, 4),
            "val_rougeL": round(rL_4, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model4, tok4, trainer4)
    print(f"\n{'='*60}")
    print("EXPERIMENT 4 COMPLETE")
    print(f"{'='*60}")
else:
    print(f"✓ {EXP4} already done — skipping training")
# Out:
# Free GPU memory: 15.5 GB
#  NOT YET DONE: exp04_flanT5base_lora_r32 — will run now.
#
# ============================================================
# EXPERIMENT 4 : exp04_flanT5base_lora_r32
# Model        : google/flan-t5-base
# LoRA         : r=32, alpha=64  ← doubled from Exp 3
# LR / Epochs  : 3e-4 / 3
# ============================================================
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# trainable params: 3,538,944 || all params: 251,116,800 || trainable%: 1.4093
# Map:   0%|          | 0/29814 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6686 [00:00<?, ? examples/s]
#  Estimated time : ~93 minutes
# Starting training...
#     <div>
#
#       <progress value='5592' max='5592' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5592/5592 2:44:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rougel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.105700</td>
#       <td>0.091000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.105700</td>
#       <td>0.091000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.105700</td>
#       <td>0.091000</td>
#     </tr>
#   </tbody>
# </table><p>
#  Model saved : /content/drive/MyDrive/multilingual_health_qa/outputs/model_exp04_flanT5base_lora_r32
# ✓ Learning curves saved : /content/drive/MyDrive/multilingual_health_qa/plots/learning_curves_exp04_flanT5base_lora_r32.png
#
# ✓ Val ROUGE-1 : 0.1057
# ✓ Val ROUGE-L : 0.0910
#
# Running inference on test set...
# Generating:   0%|          | 0/328 [00:00<?, ?it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   0%|          | 1/328 [00:02<13:23,  2.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 2/328 [00:05<15:25,  2.84s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 3/328 [00:08<14:58,  2.77s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 4/328 [00:10<13:47,  2.55s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 5/328 [00:12<13:01,  2.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 6/328 [00:14<12:34,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 7/328 [00:17<12:15,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 8/328 [00:19<13:09,  2.47s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 9/328 [00:22<13:05,  2.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 10/328 [00:24<12:36,  2.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 11/328 [00:26<12:14,  2.32s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▎         | 12/328 [00:28<12:00,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▍         | 13/328 [00:31<12:00,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▍         | 14/328 [00:34<12:50,  2.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▍         | 15/328 [00:36<12:31,  2.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▍         | 16/328 [00:38<12:32,  2.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▌         | 17/328 [00:40<12:08,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▌         | 18/328 [00:43<11:51,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▌         | 19/328 [00:45<12:12,  2.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▌         | 20/328 [00:48<12:42,  2.48s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▋         | 21/328 [00:50<12:12,  2.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 22/328 [00:52<11:48,  2.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 23/328 [00:54<11:35,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 24/328 [00:57<11:26,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 25/328 [00:59<12:03,  2.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 26/328 [01:02<12:19,  2.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 27/328 [01:04<11:49,  2.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▊         | 28/328 [01:06<11:34,  2.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 29/328 [01:08<11:22,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 30/328 [01:11<11:11,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 31/328 [01:13<11:55,  2.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|▉         | 32/328 [01:16<11:58,  2.43s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|█         | 33/328 [01:18<11:33,  2.35s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|█         | 34/328 [01:20<11:17,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█         | 35/328 [01:22<11:03,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█         | 36/328 [01:25<10:55,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█▏        | 37/328 [01:27<11:44,  2.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 38/328 [01:30<11:40,  2.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 39/328 [01:32<11:16,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 40/328 [01:34<10:59,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▎        | 41/328 [01:36<10:47,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 42/328 [01:39<10:46,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 43/328 [01:42<11:37,  2.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 44/328 [01:44<11:15,  2.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▎        | 45/328 [01:46<10:55,  2.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▍        | 46/328 [01:48<10:38,  2.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▍        | 47/328 [01:50<10:27,  2.23s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▍        | 48/328 [01:53<10:38,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▍        | 49/328 [01:56<11:28,  2.47s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▌        | 50/328 [01:58<11:02,  2.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 51/328 [02:00<10:43,  2.32s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 52/328 [02:02<10:30,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 53/328 [02:04<10:19,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▋        | 54/328 [02:07<11:09,  2.44s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 55/328 [02:10<11:20,  2.49s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 56/328 [02:12<10:48,  2.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 57/328 [02:14<10:30,  2.33s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 58/328 [02:16<10:19,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 59/328 [02:18<10:06,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 60/328 [02:21<10:43,  2.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▊        | 61/328 [02:24<10:54,  2.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▉        | 62/328 [02:26<10:30,  2.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▉        | 63/328 [02:27<08:15,  1.87s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|█▉        | 64/328 [02:27<06:41,  1.52s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|█▉        | 65/328 [02:28<05:35,  1.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|██        | 66/328 [02:29<04:48,  1.10s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|██        | 67/328 [02:29<04:14,  1.03it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██        | 68/328 [02:30<03:51,  1.12it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██        | 69/328 [02:31<03:35,  1.20it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██▏       | 70/328 [02:31<03:18,  1.30it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 71/328 [02:32<03:09,  1.36it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 72/328 [02:33<03:06,  1.37it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 73/328 [02:34<03:35,  1.19it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 74/328 [02:35<04:10,  1.01it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 75/328 [02:36<04:23,  1.04s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 76/328 [02:37<03:54,  1.08it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 77/328 [02:38<03:57,  1.06it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 78/328 [02:39<04:08,  1.01it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 79/328 [02:41<04:54,  1.18s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 80/328 [02:42<04:48,  1.16s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▍       | 81/328 [02:43<04:35,  1.11s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▌       | 82/328 [02:44<04:32,  1.11s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▌       | 83/328 [02:46<05:11,  1.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 84/328 [02:47<05:41,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 85/328 [02:49<05:26,  1.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 86/328 [02:51<06:25,  1.59s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 87/328 [02:52<06:03,  1.51s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 88/328 [02:53<05:43,  1.43s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 89/328 [02:54<05:10,  1.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 90/328 [02:56<05:27,  1.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 91/328 [02:58<06:15,  1.58s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 92/328 [02:59<05:38,  1.43s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 93/328 [03:00<05:34,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▊       | 94/328 [03:02<06:08,  1.57s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▉       | 95/328 [03:04<06:17,  1.62s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▉       | 96/328 [03:05<05:29,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|██▉       | 97/328 [03:06<04:59,  1.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|██▉       | 98/328 [03:07<04:55,  1.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|███       | 99/328 [03:08<04:32,  1.19s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|███       | 100/328 [03:10<05:14,  1.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███       | 101/328 [03:11<04:57,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███       | 102/328 [03:12<04:50,  1.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███▏      | 103/328 [03:13<04:27,  1.19s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 104/328 [03:15<04:45,  1.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 105/328 [03:17<05:16,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 106/328 [03:18<05:26,  1.47s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 107/328 [03:19<05:10,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 108/328 [03:21<04:58,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 109/328 [03:22<04:42,  1.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▎      | 110/328 [03:23<04:35,  1.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 111/328 [03:25<04:47,  1.32s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 112/328 [03:26<04:51,  1.35s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 113/328 [03:27<04:37,  1.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▍      | 114/328 [03:29<05:19,  1.50s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▌      | 115/328 [03:31<05:44,  1.62s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▌      | 116/328 [03:33<05:39,  1.60s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▌      | 117/328 [03:34<04:58,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▌      | 118/328 [03:35<04:55,  1.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▋      | 119/328 [03:37<05:21,  1.54s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 120/328 [03:38<04:49,  1.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 121/328 [03:39<04:33,  1.32s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 122/328 [03:40<04:20,  1.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 123/328 [03:42<04:31,  1.32s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 124/328 [03:43<04:54,  1.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 125/328 [03:45<04:48,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 126/328 [03:46<04:33,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▊      | 127/328 [03:47<04:11,  1.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▉      | 128/328 [03:48<04:11,  1.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▉      | 129/328 [03:50<04:43,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|███▉      | 130/328 [03:51<04:16,  1.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|███▉      | 131/328 [03:53<04:37,  1.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|████      | 132/328 [03:54<04:34,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 133/328 [03:55<04:21,  1.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 134/328 [03:57<04:31,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 135/328 [03:58<04:48,  1.49s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████▏     | 136/328 [04:00<04:25,  1.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 137/328 [04:01<04:17,  1.35s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 138/328 [04:02<04:29,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 139/328 [04:03<03:49,  1.21s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  43%|████▎     | 140/328 [04:04<03:32,  1.13s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  43%|████▎     | 141/328 [04:05<03:20,  1.07s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
# Generating:  86%|████████▌ | 282/328 [07:09<01:43,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  86%|████████▋ | 283/328 [07:11<01:38,  2.20s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 284/328 [07:13<01:31,  2.08s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 285/328 [07:15<01:23,  1.95s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 286/328 [07:17<01:21,  1.94s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 287/328 [07:19<01:21,  1.99s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 288/328 [07:22<01:29,  2.23s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 289/328 [07:24<01:31,  2.35s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 290/328 [07:26<01:26,  2.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▊ | 291/328 [07:28<01:18,  2.11s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▉ | 292/328 [07:30<01:15,  2.10s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▉ | 293/328 [07:31<01:02,  1.77s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|████████▉ | 294/328 [07:33<01:04,  1.91s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|████████▉ | 295/328 [07:35<01:05,  1.99s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|█████████ | 296/328 [07:37<00:58,  1.83s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 297/328 [07:39<00:55,  1.80s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 298/328 [07:41<00:56,  1.89s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 299/328 [07:42<00:51,  1.79s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████▏| 300/328 [07:43<00:45,  1.61s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 301/328 [07:45<00:43,  1.63s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 302/328 [07:46<00:36,  1.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 303/328 [07:48<00:39,  1.56s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 304/328 [07:50<00:38,  1.59s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 305/328 [07:50<00:31,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 306/328 [07:52<00:34,  1.57s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▎| 307/328 [07:53<00:28,  1.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▍| 308/328 [07:55<00:27,  1.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▍| 309/328 [07:56<00:25,  1.33s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▍| 310/328 [07:57<00:23,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▍| 311/328 [07:58<00:21,  1.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▌| 312/328 [07:59<00:18,  1.14s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▌| 313/328 [08:01<00:17,  1.18s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▌| 314/328 [08:03<00:21,  1.51s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▌| 315/328 [08:05<00:22,  1.72s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▋| 316/328 [08:06<00:18,  1.54s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 317/328 [08:07<00:15,  1.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 318/328 [08:08<00:13,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 319/328 [08:09<00:10,  1.22s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 320/328 [08:11<00:10,  1.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 321/328 [08:12<00:08,  1.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 322/328 [08:14<00:08,  1.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 323/328 [08:15<00:06,  1.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 324/328 [08:17<00:05,  1.49s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 325/328 [08:19<00:04,  1.58s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 326/328 [08:19<00:02,  1.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating: 100%|█████████▉| 327/328 [08:22<00:01,  1.59s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating: 100%|██████████| 328/328 [08:22<00:00,  1.53s/it]
#  Predictions saved : /content/drive/MyDrive/multilingual_health_qa/data/predictions_exp04_flanT5base_lora_r32.csv
# ✓ Experiment log updated : /content/drive/MyDrive/multilingual_health_qa/data/experiment_log.json
# {
#   "config": {
#     "model": "google/flan-t5-base",
#     "lora": true,
#     "lora_r": 32,
#     "lora_alpha": 64,
#     "learning_rate": 0.0003,
#     "epochs": 3,
#     "batch_size": 4,
#     "max_input": 128,
#     "max_target": 64,
#     "prompt_version": "v1",
#     "purpose": "Higher LoRA rank \u2014 capacity vs overfitting tradeoff"
#   },
#   "metrics": {
#     "val_rouge1": 0.1057,
#     "val_rougeL": 0.091,
#     "zindi_score": "pending"
#   }
# }
#  GPU memory freed
#   Used : 1.05 GB
#   Free : 14.33 GB
#
# ============================================================
# EXPERIMENT 4 COMPLETE
# ============================================================

# %%
# EXPERIMENT 4 — Build submission and download
from google.colab import files

EXP4 = "exp04_flanT5base_lora_r32"

sub_path4 = build_submission(EXP4)
files.download(sub_path4)
print("\n NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 4: flan-t5-base LoRA r=32'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")
# Out:
#  Submission saved  : /content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp04_flanT5base_lora_r32.csv
#   Shape             : (2618, 4)
#   Columns           : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#
# First 3 rows:
#                        ID                                                                         TargetRLF1                                                                         TargetR1F1                                                                          TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de
# 1  ID_TS_Aka_Gha_1C80317F    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n
# 2  ID_TS_Aka_Gha_06671AD1                  'bystander' is a term used to describe a person who is bystander.                  'bystander' is a term used to describe a person who is bystander.                  'bystander' is a term used to describe a person who is bystander.
#  NEXT STEPS:
# 1. Upload to Zindi → Comment: 'Exp 4: flan-t5-base LoRA r=32'
# 2. Screenshot your score
# 3. Run the cell below with your real score

# %%
# EXPERIMENT 4 — Paste your Zindi score here
ZINDI_SCORE_EXP4 = 0.152634

update_zindi_score(EXP4, ZINDI_SCORE_EXP4)
print(f"Exp 4 score recorded: {ZINDI_SCORE_EXP4}")
# Out:
# ✓ Zindi score updated: exp04_flanT5base_lora_r32 = 0.152634
# Exp 4 score recorded: 0.152634

# %%
# Disable widget metadata saving
from tqdm import tqdm
import os
os.environ["TQDM_DISABLE"] = "0"

# Tell Jupyter not to save widget state
# %config Application.log_level = 'WARN'

# %%
import os

path = "/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp04_flanT5base_lora_r32.csv"
clean_path = "/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp04_clean.csv"

print("Exp04 exists:", os.path.exists(path))
print("Exp04 clean exists:", os.path.exists(clean_path))

if os.path.exists(clean_path):
    import pandas as pd
    df = pd.read_csv(clean_path)
    print("Rows:", len(df))
# Out:
# Exp04 exists: True
# Exp04 clean exists: False

# %%
import pandas as pd
from google.colab import files

# Load the correct filename
exp04 = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp04_flanT5base_lora_r32.csv")

# Fix empty strings
for col in ['TargetRLF1', 'TargetR1F1', 'TargetLLM']:
    exp04[col] = exp04[col].astype(str).str.strip()
    exp04[col] = exp04[col].replace('', 'I do not know')

# Verify
print("Empty strings remaining:")
for col in ['TargetRLF1', 'TargetR1F1', 'TargetLLM']:
    empty = (exp04[col].str.strip() == '').sum()
    print(f"  {col}: {empty}")

# Save and download
fixed_path = "/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp04_fixed.csv"
exp04.to_csv(fixed_path, index=False)
print("Saved!")
files.download(fixed_path)
# Out:
# Empty strings remaining:
#   TargetRLF1: 0
#   TargetR1F1: 0
#   TargetLLM: 0
# Saved!

# %%
import json
notebook_path = "/content/drive/MyDrive/Colab Notebooks/03_finetuning_exp4.ipynb"
with open(notebook_path, "r") as f:
    nb = json.load(f)
if "widgets" in nb.get("metadata", {}):
    del nb["metadata"]["widgets"]
with open(notebook_path, "w") as f:
    json.dump(nb, f, indent=1)
print(" Fixed")
# Out:
#  Fixed
