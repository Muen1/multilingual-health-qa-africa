# %% [markdown]
# <a href="https://colab.research.google.com/github/Muen1/multilingual-health-qa-africa/blob/main/notebooks/03_finetuning_exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELL 0 — Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
import os

BASE_DIR = '/content/drive/MyDrive/multilingual_health_qa'
DATA_DIR = f'{BASE_DIR}/data'
OUT_DIR  = f'{BASE_DIR}/outputs'
PLOT_DIR = f'{BASE_DIR}/plots'
SUB_DIR  = f'{BASE_DIR}/submissions'

for d in [OUT_DIR, PLOT_DIR]:
    os.makedirs(d, exist_ok=True)

print("Drive mounted.")
print("Data files:", os.listdir(DATA_DIR))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted.
# Data files: ['Train.csv', 'Val.csv', 'Test.csv', 'SampleSubmission.csv', 'train_clean.csv', 'val_clean.csv', 'test_clean.csv', 'predictions_exp01_mt5small_zeroshot.csv', 'predictions_exp02_mt5small_lora_r16.csv', 'experiment_log.json']

# %%
# CELL S2 — Install only what's missing (compatible with Colab's pre-installed versions)
# !pip install -q evaluate rouge-score sentencepiece

# Verify
import importlib
packages = ['transformers', 'datasets', 'peft', 'accelerate', 'evaluate', 'rouge_score', 'sentencepiece']
print("\n=== Installed versions ===")
for p in packages:
    try:
        mod = importlib.import_module(p)
        ver = getattr(mod, '__version__', 'installed')
        print(f"  ✓ {p}: {ver}")
    except:
        print(f"  ✗ {p}: MISSING")

print("\nInstallation complete — no restart needed.")
# Out:
# === Installed versions ===
#   ✓ transformers: 5.10.2
#   ✓ datasets: 4.0.0
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
#   ✓ peft: 0.19.1
#   ✓ accelerate: 1.13.0
#   ✓ evaluate: 0.4.6
#   ✓ rouge_score: installed
#   ✓ sentencepiece: 0.2.1
#
# Installation complete — no restart needed.

# %%
# CELL S3 — Package check
import importlib, sys

required = {
    'transformers': '4.0',
    'datasets': '2.0',
    'peft': '0.5',
    'accelerate': '0.20',
    'evaluate': '0.4',
    'rouge_score': '0.1',
    'sentencepiece': '0.1',
}

print("=== Package check ===")
all_ok = True
for pkg, min_ver in required.items():
    try:
        mod = importlib.import_module(pkg)
        ver = getattr(mod, '__version__', '?')
        print(f"  ✓ {pkg}: {ver}")
    except ImportError:
        print(f"  ✗ {pkg}: MISSING")
        all_ok = False

if all_ok:
    print("\n✓ All packages present — ready to continue.")
else:
    print("\n✗ Run: !pip install -q evaluate rouge-score sentencepiece")
# Out:
# === Package check ===
#   ✓ transformers: 5.10.2
#   ✓ datasets: 4.0.0
#   ✓ peft: 0.19.1
#   ✓ accelerate: 1.13.0
#   ✓ evaluate: 0.4.6
#   ✓ rouge_score: ?
#   ✓ sentencepiece: 0.2.1
#
# ✓ All packages present — ready to continue.

# %%
# imports
import gc
import os
import json
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import evaluate as hf_evaluate
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq,
    EarlyStoppingCallback
)
from peft import get_peft_model, LoraConfig, TaskType
from datasets import Dataset

print("PyTorch version :", torch.__version__)
print("CUDA available  :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU             :", torch.cuda.get_device_name(0))
else:
    print("WARNING: No GPU detected. Go to Runtime → Change runtime type → T4 GPU")
# Out:
# PyTorch version : 2.11.0+cu128
# CUDA available  : True
# GPU             : Tesla T4

# %%
# CELL S4 — Load cleaned data
train = pd.read_csv(f'{DATA_DIR}/train_clean.csv')
val   = pd.read_csv(f'{DATA_DIR}/val_clean.csv')
test  = pd.read_csv(f'{DATA_DIR}/test_clean.csv')

# Column mapping for this dataset
q_col    = 'input'
a_col    = 'output'
lang_col = 'subset'
id_col   = 'ID'

# Rebuild prompts v1 if missing
if 'input_text' not in train.columns:
    def _prompt_v1(q, l):
        return f"Language: {l}\nQuestion: {q}\nAnswer:"
    train['input_text']  = train.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)
    train['target_text'] = train[a_col].astype(str)
    val['input_text']    = val.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)
    val['target_text']   = val[a_col].astype(str)
    test['input_text']   = test.apply(lambda r: _prompt_v1(r[q_col], r[lang_col]), axis=1)

print(f"Train: {len(train)}, Val: {len(val)}, Test: {len(test)}")
print("Sample input:", train['input_text'].iloc[0])
print("Sample target:", train['target_text'].iloc[0][:150])
# Out:
# Train: 29814, Val: 6686, Test: 2618
# Sample input: Language: Aka_Gha
# Question: Ɔkwan bɛn so na mmabunbɛtumi aboa wɔn mfɛfoɔ a nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ? Yei bi ne sɛnea wɔbɛkyekye wɔn werɛ, sɛnea wɔbɛboa wɔn ma wɔanya mmoa firi nnwumakuo a ɛfata hɔ, ne sɛnea wɔbɛsiw afɔbu suban ne nsɛm a nkurɔfoɔ de gu oyarefoɔ no so no kwan.
# Answer:
# Sample target: Mmabun betumi aboa atipɛnfo a ebia nsa anaa nnubɔne ama wɔayɛ wɔn ayayadeɛ so denam: Nkate fam mmoa a wɔde bɛma na wɔagye wɔn nkate atom a wɔremmu atɛ

# %%
# CELL S5 — Load sample submission and verify format
sample = pd.read_csv(f'{DATA_DIR}/SampleSubmission.csv')
print(" Sample submission loaded")
print(f"  Columns : {sample.columns.tolist()}")
print(f"  Shape   : {sample.shape}")
print(f"\nFirst 2 rows:")
print(sample.head(2).to_string())
# Out:
#  Sample submission loaded
#   Columns : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#   Shape   : (2618, 4)
#
# First 2 rows:
#                        ID             TargetRLF1             TargetR1F1              TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  Wuna dey craze, eweeh  Wuna dey craze, eweeh  Wuna dey craze, eweeh
# 1  ID_TS_Aka_Gha_1C80317F  Wuna dey craze, eweeh  Wuna dey craze, eweeh  Wuna dey craze, eweeh

# %%
# CELL S6 — All shared helper functions

#  1. ROUGE metric
rouge_metric = hf_evaluate.load("rouge")

#  2. Tokenize datasets
def get_tokenized_datasets(tokenizer, train_df, val_df,
                            max_input=128, max_target=64):
    def preprocess(examples):
        inputs = tokenizer(
            examples['input_text'],
            max_length=max_input,
            truncation=True,
            padding='max_length'
        )
        targets = tokenizer(
            examples['target_text'],
            max_length=max_target,
            truncation=True,
            padding='max_length'
        )
        labels = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label]
            for label in targets['input_ids']
        ]
        inputs['labels'] = labels
        return inputs

    train_ds  = Dataset.from_pandas(
        train_df[['input_text','target_text']].reset_index(drop=True))
    val_ds    = Dataset.from_pandas(
        val_df[['input_text','target_text']].reset_index(drop=True))
    train_tok = train_ds.map(preprocess, batched=True,
                             remove_columns=['input_text','target_text'])
    val_tok   = val_ds.map(preprocess,   batched=True,
                           remove_columns=['input_text','target_text'])
    return train_tok, val_tok

# 3. Compute metrics
def make_compute_metrics(tokenizer):
    def compute_metrics(eval_preds):
        preds, labels = eval_preds
        if isinstance(preds, tuple):
            preds = preds[0]

        preds  = np.where(preds  != -100, preds,  tokenizer.pad_token_id)
        labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
        preds  = np.clip(preds, 0, tokenizer.vocab_size - 1)

        decoded_preds  = tokenizer.batch_decode(
            preds,  skip_special_tokens=True)
        decoded_labels = tokenizer.batch_decode(
            labels, skip_special_tokens=True)
        decoded_preds  = [p.strip() for p in decoded_preds]
        decoded_labels = [l.strip() for l in decoded_labels]
        result = rouge_metric.compute(
            predictions=decoded_preds,
            references=decoded_labels,
            use_stemmer=True
        )
        return {
            "rouge1": round(result["rouge1"], 4),
            "rougeL": round(result["rougeL"], 4)
        }
    return compute_metrics

# 4. Training
def run_training(model, tokenizer, train_tok, val_tok,
                 experiment_name, learning_rate,
                 num_epochs, batch_size, max_target_len):
    args = Seq2SeqTrainingArguments(
        output_dir=f"{OUT_DIR}/checkpoints_{experiment_name}",
        num_train_epochs=num_epochs,
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        gradient_accumulation_steps=4,
        warmup_steps=50,
        learning_rate=learning_rate,
        weight_decay=0.01,
        fp16=True,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="eval_loss",
        predict_with_generate=True,
        generation_max_length=64,
        logging_steps=50,
        report_to="none",
        push_to_hub=False
    )
    collator = DataCollatorForSeq2Seq(tokenizer, model=model, padding=True)
    trainer  = Seq2SeqTrainer(
        model=model,
        args=args,
        train_dataset=train_tok,
        eval_dataset=val_tok,
        processing_class=tokenizer,
        data_collator=collator,
        compute_metrics=make_compute_metrics(tokenizer),
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
    )
    est = len(train_tok) * num_epochs / (4 * 4) / 60
    print(f" Estimated time : ~{est:.0f} minutes")
    print("Starting training...")
    trainer.train(resume_from_checkpoint=True)
    return trainer

# 5. Save model
def save_model(model, tokenizer, experiment_name):
    path = f'{OUT_DIR}/model_{experiment_name}'
    os.makedirs(path, exist_ok=True)
    model.save_pretrained(path)
    tokenizer.save_pretrained(path)
    print(f" Model saved : {path}")
    return path

# 6. Generate answers
def generate_answers(model, tokenizer, texts,
                     max_input=128, max_target=64,
                     batch_size=8, num_beams=4):
    model.eval()
    if torch.cuda.is_available():
        model = model.cuda()
    all_answers = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Generating"):
        batch  = texts[i:i+batch_size]
        inputs = tokenizer(
            batch, return_tensors='pt',
            max_length=max_input,
            truncation=True, padding=True
        )
        if torch.cuda.is_available():
            inputs = {k: v.cuda() for k, v in inputs.items()}
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_target,
                num_beams=num_beams,
                no_repeat_ngram_size=3,
                length_penalty=1.0
            )
        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        all_answers.extend(decoded)
    return all_answers

# 7. Save predictions
def save_predictions(test_df, answers, experiment_name):
    out              = test_df.copy()
    out['predicted_answer'] = answers
    path             = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    out.to_csv(path, index=False)
    print(f" Predictions saved : {path}")
    return path

# 8. Build Zindi submission
def build_submission(experiment_name):
    pred_path = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    if not os.path.exists(pred_path):
        print(f"✗ No predictions found for {experiment_name}")
        print(f"  Expected at: {pred_path}")
        return None

    preds       = pd.read_csv(pred_path)
    pred_id_col = preds.columns[0]
    pred_answer = preds['predicted_answer'].astype(str).values

    submission  = pd.DataFrame({
        'ID':         preds[pred_id_col].values,
        'TargetRLF1': pred_answer,
        'TargetR1F1': pred_answer,
        'TargetLLM':  pred_answer
    })

    assert list(submission.columns) == ['ID','TargetRLF1','TargetR1F1','TargetLLM'], \
        "Column mismatch!"
    assert len(submission) == len(sample), \
        f"Row mismatch: {len(submission)} vs {len(sample)}"
    assert submission.isnull().sum().sum() == 0, \
        "Null values found!"

    path = f'{SUB_DIR}/submission_{experiment_name}.csv'
    submission.to_csv(path, index=False)
    print(f" Submission saved  : {path}")
    print(f"  Shape             : {submission.shape}")
    print(f"  Columns           : {submission.columns.tolist()}")
    print(f"\nFirst 3 rows:")
    print(submission.head(3).to_string())
    return path

# 9. Plot learning curves
def plot_learning_curves(trainer, experiment_name):
    log      = trainer.state.log_history
    t_steps  = [x['step']      for x in log
                if 'loss' in x and 'eval_loss' not in x]
    t_losses = [x['loss']      for x in log
                if 'loss' in x and 'eval_loss' not in x]
    e_epochs = [x['epoch']     for x in log if 'eval_loss' in x]
    e_losses = [x['eval_loss'] for x in log if 'eval_loss' in x]
    e_r1     = [x.get('eval_rouge1', 0) for x in log if 'eval_loss' in x]
    e_rL     = [x.get('eval_rougeL', 0) for x in log if 'eval_loss' in x]

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(f'Learning Curves — {experiment_name}',
                 fontsize=13, fontweight='bold')

    axes[0].plot(t_steps, t_losses, color='royalblue', linewidth=1.5)
    axes[0].set_title('Training Loss')
    axes[0].set_xlabel('Step')
    axes[0].set_ylabel('Loss')
    axes[0].grid(True, alpha=0.4)

    axes[1].plot(e_epochs, e_losses, color='darkorange',
                 marker='o', linewidth=2)
    axes[1].set_title('Validation Loss per Epoch')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Eval Loss')
    axes[1].grid(True, alpha=0.4)

    axes[2].plot(e_epochs, e_r1, color='green',
                 marker='o', linewidth=2, label='ROUGE-1')
    axes[2].plot(e_epochs, e_rL, color='purple',
                 marker='s', linewidth=2, label='ROUGE-L')
    axes[2].set_title('ROUGE Scores per Epoch')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('F1 Score')
    axes[2].legend()
    axes[2].grid(True, alpha=0.4)

    plt.tight_layout()
    path = f'{PLOT_DIR}/learning_curves_{experiment_name}.png'
    plt.savefig(path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"✓ Learning curves saved : {path}")

#  10. Experiment log
LOG_PATH = f'{DATA_DIR}/experiment_log.json'

def save_experiment_log(experiment_name, config, metrics):
    log = {}
    if os.path.exists(LOG_PATH):
        with open(LOG_PATH, 'r') as f:
            log = json.load(f)
    log[experiment_name] = {"config": config, "metrics": metrics}
    with open(LOG_PATH, 'w') as f:
        json.dump(log, f, indent=2)
    print(f"✓ Experiment log updated : {LOG_PATH}")
    print(json.dumps(log[experiment_name], indent=2))

def update_zindi_score(experiment_name, score):
    if not os.path.exists(LOG_PATH):
        print("No log file found. Run the experiment first.")
        return
    with open(LOG_PATH, 'r') as f:
        log = json.load(f)
    if experiment_name not in log:
        print(f"Experiment {experiment_name} not in log.")
        return
    log[experiment_name]['metrics']['zindi_score'] = score
    with open(LOG_PATH, 'w') as f:
        json.dump(log, f, indent=2)
    print(f"✓ Zindi score updated: {experiment_name} = {score}")

# 11. Check if already done
def is_done(experiment_name):
    pred_path = f'{DATA_DIR}/predictions_{experiment_name}.csv'
    if os.path.exists(pred_path):
        print(f"✓ ALREADY DONE: {experiment_name}")
        print(f"  Predictions at: {pred_path}")
        print("  Skipping to submission cell.")
        return True
    print(f" NOT YET DONE: {experiment_name} — will run now.")
    return False

# 12. Free GPU memory
def free_gpu(*objects):
    for obj in objects:
        del obj
    gc.collect()
    torch.cuda.empty_cache()
    if torch.cuda.is_available():
        used = torch.cuda.memory_allocated() / 1e9
        free = torch.cuda.mem_get_info()[0] / 1e9
        print(f" GPU memory freed")
        print(f"  Used : {used:.2f} GB")
        print(f"  Free : {free:.2f} GB")

print("✓ All helper functions loaded and ready.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✓ All helper functions loaded and ready.

# %%
import os
checkpoint_dir = "/content/drive/MyDrive/multilingual_health_qa/outputs/checkpoints_exp03_flanT5base_lora_r16"
if os.path.exists(checkpoint_dir):
    print("✅ Checkpoints found:", os.listdir(checkpoint_dir))
else:
    print("❌ No checkpoints found — will start from scratch")
# Out:
# ✅ Checkpoints found: ['checkpoint-1864', 'checkpoint-3728']

# %%
# CELL S7 — Check what experiments are already done
import os, json

print("=== EXPERIMENT STATUS ===\n")

experiments_list = [
    "exp01_mt5small_zeroshot",
    "exp02_mt5small_lora_r16",
    "exp03_flanT5base_lora_r16",
    "exp04_flanT5base_lora_r32",
    "exp05_flanT5base_promptv2",
    "exp06_flanT5large_lora_r16"
]

for exp in experiments_list:
    pred_path = f'{DATA_DIR}/predictions_{exp}.csv'
    sub_path  = f'{DATA_DIR}/../submissions/submission_{exp}.csv'
    done      = "✓ DONE" if os.path.exists(pred_path) else "✗ NOT DONE"
    submitted = "✓ SUBMITTED" if os.path.exists(sub_path) else "✗ NOT SUBMITTED"
    print(f"{exp}")
    print(f"  Predictions : {done}")
    print(f"  Submission  : {submitted}")
    print()

if os.path.exists(LOG_PATH):
    print("=== SCORES SO FAR ===")
    with open(LOG_PATH, 'r') as f:
        log = json.load(f)
    for name, entry in log.items():
        m = entry.get('metrics', {})
        print(f"  {name}")
        print(f"    ROUGE-1    : {m.get('val_rouge1', 'N/A')}")
        print(f"    ROUGE-L    : {m.get('val_rougeL', 'N/A')}")
        print(f"    Zindi Score: {m.get('zindi_score', 'not yet')}")
        print()
else:
    print("No experiment log yet — starting fresh.")
# Out:
# === EXPERIMENT STATUS ===
#
# exp01_mt5small_zeroshot
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp02_mt5small_lora_r16
#   Predictions : ✓ DONE
#   Submission  : ✓ SUBMITTED
#
# exp03_flanT5base_lora_r16
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp04_flanT5base_lora_r32
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp05_flanT5base_promptv2
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# exp06_flanT5large_lora_r16
#   Predictions : ✗ NOT DONE
#   Submission  : ✗ NOT SUBMITTED
#
# === SCORES SO FAR ===
#   exp02_mt5small_lora_r16
#     ROUGE-1    : 0.0034
#     ROUGE-L    : 0.0033
#     Zindi Score: 0.004928

# %%
# FIX — Upgrade torchao to fix peft compatibility
# RUN ONLY ONCE
# !pip install -q --upgrade torchao

# Restart runtime after this installs
import os
os.kill(os.getpid(), 9)

# %%
# Confirm torchao version is correct
import torchao
import peft
import torch

print(f"torchao : {torchao.__version__}")
print(f"peft    : {peft.__version__}")
print(f"torch   : {torch.__version__}")
print(f"GPU     : {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NOT AVAILABLE'}")

# Quick test that get_peft_model works without the ImportError
from peft import LoraConfig, TaskType, get_peft_model
from transformers import AutoModelForSeq2SeqLM

print("\nTesting peft import...")
test_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
test_lora  = LoraConfig(task_type=TaskType.SEQ_2_SEQ_LM, r=8, lora_alpha=16,
                         target_modules=["q", "v"], bias="none")
test_model = get_peft_model(test_model, test_lora)
print("✓ get_peft_model works correctly")
print("✓ Ready to run experiments")

del test_model
# Out:
# torchao : 0.17.0
# peft    : 0.19.1
# torch   : 2.11.0+cu128
# GPU     : Tesla T4
#
# Testing peft import...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# ✓ get_peft_model works correctly
# ✓ Ready to run experiments

# %%
# EXPERIMENT 3 — flan-t5-base with LoRA r=16
# WHAT    : Switch backbone from mt5-small to flan-t5-base
# WHY     : Flan-T5 was instruction-tuned; it already understands
#           QA format. mt5 is pretrained only (no instruction
#           tuning), so flan-t5-base should outperform it even
#           with the same LoRA config. Model is the only variable.
# CHANGE  : Model: mt5-small → flan-t5-base

# Free any leftover GPU memory before starting
import gc, torch
gc.collect()
torch.cuda.empty_cache()
print(f"Free GPU memory: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB")

EXP3 = "exp03_flanT5base_lora_r16"

if not is_done(EXP3):
    print(f"\n{'='*60}")
    print(f"EXPERIMENT 3 : {EXP3}")
    print(f"Model        : google/flan-t5-base")
    print(f"LoRA         : r=16, alpha=32")
    print(f"LR / Epochs  : 3e-4 / 3")
    print(f"{'='*60}\n")

    tok3   = AutoTokenizer.from_pretrained("google/flan-t5-base")
    model3 = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")
    print(f"Parameters : {model3.num_parameters():,}")

    lora3 = LoraConfig(
        task_type=TaskType.SEQ_2_SEQ_LM,
        r=16, lora_alpha=32,
        target_modules=["q", "v"],
        lora_dropout=0.1, bias="none"
    )
    model3 = get_peft_model(model3, lora3)
    model3.print_trainable_parameters()

    train_tok3, val_tok3 = get_tokenized_datasets(
        tok3, train, val,
        max_input=128, max_target=64)

    trainer3 = run_training(
        model3, tok3, train_tok3, val_tok3,
        experiment_name=EXP3,
        learning_rate=3e-4, num_epochs=3,
        batch_size=4, max_target_len=64
    )

    save_model(model3, tok3, EXP3)
    plot_learning_curves(trainer3, EXP3)

    log3  = trainer3.state.log_history
    best3 = [x for x in log3 if 'eval_rouge1' in x]
    r1_3  = best3[-1]['eval_rouge1'] if best3 else 0.0
    rL_3  = best3[-1]['eval_rougeL'] if best3 else 0.0
    print(f"\n✓ Val ROUGE-1 : {r1_3:.4f}")
    print(f"✓ Val ROUGE-L : {rL_3:.4f}")

    print("\nRunning inference on test set...")
    answers3 = generate_answers(
        model3, tok3,
        test['input_text'].tolist(),
        batch_size=8, num_beams=4
    )
    save_predictions(test, answers3, EXP3)

    save_experiment_log(
        EXP3,
        config={
            "model": "google/flan-t5-base",
            "lora": True, "lora_r": 16, "lora_alpha": 32,
            "learning_rate": 3e-4, "epochs": 3,
            "batch_size": 4,
            "max_input": 128,
            "max_target": 64,
            "prompt_version": "v1",
            "purpose": "Instruction-tuned model vs mt5-small"
        },
        metrics={
            "val_rouge1": round(r1_3, 4),
            "val_rougeL": round(rL_3, 4),
            "zindi_score": "pending"
        }
    )

    free_gpu(model3, tok3, trainer3)
    print(f"\n{'='*60}")
    print("EXPERIMENT 3 COMPLETE")
    print(f"{'='*60}")
else:
    print(f"✓ {EXP3} already done — skipping training")
# Out:
# Free GPU memory: 15.5 GB
#  NOT YET DONE: exp03_flanT5base_lora_r16 — will run now.
#
# ============================================================
# EXPERIMENT 3 : exp03_flanT5base_lora_r16
# Model        : google/flan-t5-base
# LoRA         : r=16, alpha=32
# LR / Epochs  : 3e-4 / 3
# ============================================================
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Parameters : 247,577,856
# trainable params: 1,769,472 || all params: 249,347,328 || trainable%: 0.7096
# Map:   0%|          | 0/29814 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6686 [00:00<?, ? examples/s]
#  Estimated time : ~93 minutes
# Starting training...
#     <div>
#
#       <progress value='5592' max='5592' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5592/5592 54:47, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rougel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.105600</td>
#       <td>0.091000</td>
#     </tr>
#   </tbody>
# </table><p>
#  Model saved : /content/drive/MyDrive/multilingual_health_qa/outputs/model_exp03_flanT5base_lora_r16
# ✓ Learning curves saved : /content/drive/MyDrive/multilingual_health_qa/plots/learning_curves_exp03_flanT5base_lora_r16.png
#
# ✓ Val ROUGE-1 : 0.1056
# ✓ Val ROUGE-L : 0.0910
#
# Running inference on test set...
# Generating:   0%|          | 0/328 [00:00<?, ?it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   0%|          | 1/328 [00:03<16:32,  3.03s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 2/328 [00:05<14:09,  2.61s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 3/328 [00:07<13:15,  2.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   1%|          | 4/328 [00:09<12:43,  2.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 5/328 [00:11<12:17,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 6/328 [00:14<13:10,  2.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 7/328 [00:17<13:03,  2.44s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   2%|▏         | 8/328 [00:19<12:36,  2.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 9/328 [00:21<12:14,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 10/328 [00:23<11:58,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   3%|▎         | 11/328 [00:26<12:01,  2.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▎         | 12/328 [00:28<12:57,  2.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▍         | 13/328 [00:31<12:27,  2.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   4%|▍         | 14/328 [00:33<12:03,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▍         | 15/328 [00:35<11:46,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▍         | 16/328 [00:37<11:37,  2.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▌         | 17/328 [00:40<11:55,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   5%|▌         | 18/328 [00:42<12:46,  2.47s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▌         | 19/328 [00:45<12:16,  2.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▌         | 20/328 [00:47<11:57,  2.33s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   6%|▋         | 21/328 [00:49<11:43,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 22/328 [00:51<11:25,  2.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 23/328 [00:54<11:52,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   7%|▋         | 24/328 [00:56<12:19,  2.43s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 25/328 [00:58<11:50,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 26/328 [01:01<11:30,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   8%|▊         | 27/328 [01:03<11:15,  2.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▊         | 28/328 [01:05<11:03,  2.21s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 29/328 [01:07<11:34,  2.32s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 30/328 [01:10<12:23,  2.49s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:   9%|▉         | 31/328 [01:13<11:55,  2.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|▉         | 32/328 [01:15<11:33,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|█         | 33/328 [01:17<11:15,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  10%|█         | 34/328 [01:19<11:02,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█         | 35/328 [01:22<11:50,  2.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█         | 36/328 [01:24<11:49,  2.43s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  11%|█▏        | 37/328 [01:27<11:26,  2.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 38/328 [01:29<11:05,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 39/328 [01:31<10:50,  2.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▏        | 40/328 [01:33<10:55,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  12%|█▎        | 41/328 [01:36<11:44,  2.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 42/328 [01:38<11:29,  2.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 43/328 [01:41<11:07,  2.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  13%|█▎        | 44/328 [01:43<10:49,  2.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▎        | 45/328 [01:45<10:39,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▍        | 46/328 [01:47<10:50,  2.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  14%|█▍        | 47/328 [01:50<11:37,  2.48s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▍        | 48/328 [01:52<11:09,  2.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▍        | 49/328 [01:55<10:48,  2.33s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  15%|█▌        | 50/328 [01:57<10:33,  2.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 51/328 [01:59<10:25,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 52/328 [02:02<10:50,  2.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▌        | 53/328 [02:04<11:12,  2.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  16%|█▋        | 54/328 [02:06<10:49,  2.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 55/328 [02:09<10:31,  2.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 56/328 [02:11<10:15,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  17%|█▋        | 57/328 [02:13<10:05,  2.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 58/328 [02:16<10:39,  2.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 59/328 [02:18<10:55,  2.44s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  18%|█▊        | 60/328 [02:20<10:29,  2.35s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▊        | 61/328 [02:22<10:13,  2.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▉        | 62/328 [02:25<10:01,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  19%|█▉        | 63/328 [02:25<07:54,  1.79s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|█▉        | 64/328 [02:26<06:26,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|█▉        | 65/328 [02:27<05:24,  1.23s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|██        | 66/328 [02:28<04:50,  1.11s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  20%|██        | 67/328 [02:29<04:39,  1.07s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██        | 68/328 [02:29<04:27,  1.03s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██        | 69/328 [02:30<04:18,  1.00it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  21%|██▏       | 70/328 [02:31<03:57,  1.09it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 71/328 [02:32<03:37,  1.18it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 72/328 [02:32<03:21,  1.27it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  22%|██▏       | 73/328 [02:33<03:25,  1.24it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 74/328 [02:34<03:36,  1.17it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 75/328 [02:35<03:32,  1.19it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 76/328 [02:36<03:16,  1.28it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  23%|██▎       | 77/328 [02:37<03:33,  1.18it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 78/328 [02:38<03:52,  1.08it/s][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 79/328 [02:39<04:42,  1.13s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  24%|██▍       | 80/328 [02:41<04:38,  1.12s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▍       | 81/328 [02:42<04:49,  1.17s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▌       | 82/328 [02:43<05:08,  1.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  25%|██▌       | 83/328 [02:45<06:00,  1.47s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 84/328 [02:47<05:54,  1.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 85/328 [02:48<05:08,  1.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  26%|██▌       | 86/328 [02:49<05:36,  1.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 87/328 [02:51<05:36,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 88/328 [02:52<05:24,  1.35s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 89/328 [02:53<04:56,  1.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  27%|██▋       | 90/328 [02:54<05:22,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 91/328 [02:57<07:21,  1.86s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 92/328 [02:59<06:36,  1.68s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  28%|██▊       | 93/328 [03:00<06:07,  1.56s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▊       | 94/328 [03:01<05:52,  1.51s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▉       | 95/328 [03:03<05:40,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  29%|██▉       | 96/328 [03:04<05:03,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|██▉       | 97/328 [03:05<04:37,  1.20s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|██▉       | 98/328 [03:06<04:40,  1.22s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|███       | 99/328 [03:07<04:22,  1.15s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  30%|███       | 100/328 [03:09<05:26,  1.43s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███       | 101/328 [03:11<05:32,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███       | 102/328 [03:12<05:29,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  31%|███▏      | 103/328 [03:13<04:55,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 104/328 [03:14<04:44,  1.27s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 105/328 [03:15<04:46,  1.28s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  32%|███▏      | 106/328 [03:17<04:49,  1.30s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 107/328 [03:18<04:38,  1.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 108/328 [03:19<04:37,  1.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  33%|███▎      | 109/328 [03:20<04:28,  1.23s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▎      | 110/328 [03:22<04:33,  1.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 111/328 [03:24<05:15,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 112/328 [03:25<05:38,  1.57s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  34%|███▍      | 113/328 [03:27<05:11,  1.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▍      | 114/328 [03:28<05:16,  1.48s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▌      | 115/328 [03:30<05:15,  1.48s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  35%|███▌      | 116/328 [03:31<05:23,  1.53s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▌      | 117/328 [03:32<04:47,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▌      | 118/328 [03:34<04:50,  1.39s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  36%|███▋      | 119/328 [03:36<05:27,  1.57s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 120/328 [03:37<05:15,  1.52s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 121/328 [03:39<05:16,  1.53s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  37%|███▋      | 122/328 [03:40<04:51,  1.41s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 123/328 [03:41<04:41,  1.37s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 124/328 [03:42<04:34,  1.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 125/328 [03:43<04:14,  1.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  38%|███▊      | 126/328 [03:45<04:10,  1.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▊      | 127/328 [03:46<03:51,  1.15s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▉      | 128/328 [03:47<03:55,  1.18s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  39%|███▉      | 129/328 [03:49<04:37,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|███▉      | 130/328 [03:50<04:34,  1.38s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|███▉      | 131/328 [03:52<05:21,  1.63s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  40%|████      | 132/328 [03:54<05:05,  1.56s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 133/328 [03:55<04:26,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 134/328 [03:56<04:10,  1.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████      | 135/328 [03:57<04:09,  1.29s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  41%|████▏     | 136/328 [03:58<03:55,  1.23s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 137/328 [03:59<03:59,  1.25s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 138/328 [04:01<04:18,  1.36s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  42%|████▏     | 139/328 [04:02<03:41,  1.17s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  43%|████▎     | 140/328 [04:03<03:38,  1.16s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  43%|████▎     | 141/328 [04:04<03:40,  1.18s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
# Generating:  86%|████████▌ | 282/328 [07:10<01:35,  2.07s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  86%|████████▋ | 283/328 [07:12<01:34,  2.09s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 284/328 [07:15<01:35,  2.17s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 285/328 [07:17<01:32,  2.14s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  87%|████████▋ | 286/328 [07:19<01:27,  2.08s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 287/328 [07:21<01:25,  2.08s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 288/328 [07:23<01:24,  2.11s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 289/328 [07:25<01:22,  2.12s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  88%|████████▊ | 290/328 [07:28<01:24,  2.22s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▊ | 291/328 [07:30<01:23,  2.26s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▉ | 292/328 [07:32<01:19,  2.20s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  89%|████████▉ | 293/328 [07:33<01:04,  1.84s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|████████▉ | 294/328 [07:35<01:05,  1.92s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|████████▉ | 295/328 [07:37<01:01,  1.87s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  90%|█████████ | 296/328 [07:38<00:53,  1.69s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 297/328 [07:40<00:53,  1.72s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 298/328 [07:43<01:01,  2.04s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████ | 299/328 [07:45<00:56,  1.96s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  91%|█████████▏| 300/328 [07:46<00:48,  1.74s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 301/328 [07:48<00:47,  1.75s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 302/328 [07:48<00:38,  1.48s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  92%|█████████▏| 303/328 [07:50<00:36,  1.48s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 304/328 [07:51<00:33,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 305/328 [07:52<00:27,  1.21s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  93%|█████████▎| 306/328 [07:54<00:33,  1.53s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▎| 307/328 [07:55<00:30,  1.44s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▍| 308/328 [07:57<00:31,  1.56s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  94%|█████████▍| 309/328 [07:58<00:27,  1.45s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▍| 310/328 [08:00<00:25,  1.40s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▍| 311/328 [08:01<00:22,  1.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▌| 312/328 [08:02<00:18,  1.17s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  95%|█████████▌| 313/328 [08:03<00:17,  1.14s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▌| 314/328 [08:04<00:18,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▌| 315/328 [08:07<00:20,  1.56s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  96%|█████████▋| 316/328 [08:08<00:18,  1.50s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 317/328 [08:09<00:16,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 318/328 [08:11<00:14,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  97%|█████████▋| 319/328 [08:12<00:12,  1.33s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 320/328 [08:13<00:10,  1.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 321/328 [08:15<00:09,  1.34s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 322/328 [08:16<00:08,  1.46s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  98%|█████████▊| 323/328 [08:17<00:06,  1.24s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 324/328 [08:18<00:05,  1.31s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 325/328 [08:20<00:04,  1.51s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating:  99%|█████████▉| 326/328 [08:22<00:02,  1.42s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating: 100%|█████████▉| 327/328 [08:24<00:01,  1.82s/it][transformers] Both `max_new_tokens` (=64) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generating: 100%|██████████| 328/328 [08:25<00:00,  1.54s/it]
#  Predictions saved : /content/drive/MyDrive/multilingual_health_qa/data/predictions_exp03_flanT5base_lora_r16.csv
# ✓ Experiment log updated : /content/drive/MyDrive/multilingual_health_qa/data/experiment_log.json
# {
#   "config": {
#     "model": "google/flan-t5-base",
#     "lora": true,
#     "lora_r": 16,
#     "lora_alpha": 32,
#     "learning_rate": 0.0003,
#     "epochs": 3,
#     "batch_size": 4,
#     "max_input": 128,
#     "max_target": 64,
#     "prompt_version": "v1",
#     "purpose": "Instruction-tuned model vs mt5-small"
#   },
#   "metrics": {
#     "val_rouge1": 0.1056,
#     "val_rougeL": 0.091,
#     "zindi_score": "pending"
#   }
# }
#  GPU memory freed
#   Used : 1.03 GB
#   Free : 14.36 GB
#
# ============================================================
# EXPERIMENT 3 COMPLETE
# ============================================================

# %%
# EXPERIMENT 3 — Build submission and download
from google.colab import files

sub_path3 = build_submission(EXP3)
files.download(sub_path3)
print("\n NEXT STEPS:")
print("1. Upload to Zindi → Comment: 'Exp 3: flan-t5-base LoRA r=16'")
print("2. Screenshot your score")
print("3. Run the cell below with your real score")
# Out:
#  Submission saved  : /content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp03_flanT5base_lora_r16.csv
#   Shape             : (2618, 4)
#   Columns           : ['ID', 'TargetRLF1', 'TargetR1F1', 'TargetLLM']
#
# First 3 rows:
#                        ID                                                                         TargetRLF1                                                                         TargetR1F1                                                                          TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de
# 1  ID_TS_Aka_Gha_1C80317F    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n
# 2  ID_TS_Aka_Gha_06671AD1                  'bystander' is a term used to describe a person who is bystander.                  'bystander' is a term used to describe a person who is bystander.                  'bystander' is a term used to describe a person who is bystander.
#  NEXT STEPS:
# 1. Upload to Zindi → Comment: 'Exp 3: flan-t5-base LoRA r=16'
# 2. Screenshot your score
# 3. Run the cell below with your real score

# %%
import pandas as pd

# Load sample submission to get ALL expected IDs
sample = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/data/SampleSubmission.csv")
print("Sample total rows:", len(sample))

# Check exp03
exp03 = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp03_flanT5base_lora_r16.csv")
print("Exp03 rows:", len(exp03))
missing03 = set(sample['ID']) - set(exp03['ID'])
print("Exp03 missing IDs:", len(missing03))

# Check exp04 clean
exp04 = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp04_clean.csv")
print("Exp04 rows:", len(exp04))
missing04 = set(sample['ID']) - set(exp04['ID'])
print("Exp04 missing IDs:", len(missing04))
# Out:
# Sample total rows: 2618
# Exp03 rows: 2618
# Exp03 missing IDs: 0
# Exp04 rows: 2618
# Exp04 missing IDs: 0

# %%
import pandas as pd

sample = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/data/SampleSubmission.csv")
exp03 = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp03_flanT5base_lora_r16.csv")

# Check which IDs are in sample but NOT in exp03
missing = sample[~sample['ID'].isin(exp03['ID'])]
print("Missing count:", len(missing))

# Check ID formats in both
print("\nSample ID examples:")
print(sample['ID'].head(10).tolist())

print("\nExp03 ID examples:")
print(exp03['ID'].head(10).tolist())

# Check if IDs have different formatting
print("\nSample ID lengths:", sample['ID'].str.len().describe())
print("Exp03 ID lengths:", exp03['ID'].str.len().describe())
# Out:
# Missing count: 0
#
# Sample ID examples:
# ['ID_TS_Aka_Gha_A3B1799D', 'ID_TS_Aka_Gha_1C80317F', 'ID_TS_Aka_Gha_06671AD1', 'ID_TS_Aka_Gha_BDD640FB', 'ID_TS_Aka_Gha_46685257', 'ID_TS_Aka_Gha_3EB13B90', 'ID_TS_Aka_Gha_392456DE', 'ID_TS_Aka_Gha_23B8C1E9', 'ID_TS_Aka_Gha_BC8960A9', 'ID_TS_Aka_Gha_1A3D1FA7']
#
# Exp03 ID examples:
# ['ID_TS_Aka_Gha_A3B1799D', 'ID_TS_Aka_Gha_1C80317F', 'ID_TS_Aka_Gha_06671AD1', 'ID_TS_Aka_Gha_BDD640FB', 'ID_TS_Aka_Gha_46685257', 'ID_TS_Aka_Gha_3EB13B90', 'ID_TS_Aka_Gha_392456DE', 'ID_TS_Aka_Gha_23B8C1E9', 'ID_TS_Aka_Gha_BC8960A9', 'ID_TS_Aka_Gha_1A3D1FA7']
#
# Sample ID lengths: count    2618.0
# mean       22.0
# std         0.0
# min        22.0
# 25%        22.0
# 50%        22.0
# 75%        22.0
# max        22.0
# Name: ID, dtype: float64
# Exp03 ID lengths: count    2618.0
# mean       22.0
# std         0.0
# min        22.0
# 25%        22.0
# 50%        22.0
# 75%        22.0
# max        22.0
# Name: ID, dtype: float64

# %%
import pandas as pd

exp03 = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp03_flanT5base_lora_r16.csv")

# Check for NaN or empty values in target columns
print("NaN per column:")
print(exp03.isnull().sum())

print("\nEmpty strings per column:")
for col in ['TargetRLF1', 'TargetR1F1', 'TargetLLM']:
    empty = (exp03[col].astype(str).str.strip() == '').sum()
    print(f"  {col}: {empty} empty")

print("\nSample of all columns:")
print(exp03.head(3).to_string())

# Check file encoding
print("\nFile size:", exp03.shape)
print("Dtypes:", exp03.dtypes.tolist())
# Out:
# NaN per column:
# ID            0
# TargetRLF1    0
# TargetR1F1    0
# TargetLLM     0
# dtype: int64
#
# Empty strings per column:
#   TargetRLF1: 31 empty
#   TargetR1F1: 31 empty
#   TargetLLM: 31 empty
#
# Sample of all columns:
#                        ID                                                                         TargetRLF1                                                                         TargetR1F1                                                                          TargetLLM
# 0  ID_TS_Aka_Gha_A3B1799D  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de  Aka_Gha: Fa nene a wde by nkyerkyer nnema, adwumaybea ahorow, ne akuo aborow a de
# 1  ID_TS_Aka_Gha_1C80317F    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n    n nea ebetumi afi hokwan a mmabun wnya nipadua mu ahofadi l na o akwahosan ho n
# 2  ID_TS_Aka_Gha_06671AD1                  'bystander' is a term used to describe a person who is bystander.                  'bystander' is a term used to describe a person who is bystander.                  'bystander' is a term used to describe a person who is bystander.
#
# File size: (2618, 4)
# Dtypes: [dtype('O'), dtype('O'), dtype('O'), dtype('O')]

# %%
import pandas as pd
from google.colab import files

# Fix exp03
exp03 = pd.read_csv("/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp03_flanT5base_lora_r16.csv")

# Fill empty strings with a default answer
for col in ['TargetRLF1', 'TargetR1F1', 'TargetLLM']:
    exp03[col] = exp03[col].astype(str).str.strip()
    exp03[col] = exp03[col].replace('', 'I do not know')

# Verify fix
print("Empty strings remaining:")
for col in ['TargetRLF1', 'TargetR1F1', 'TargetLLM']:
    empty = (exp03[col].str.strip() == '').sum()
    print(f"  {col}: {empty}")

# Save fixed version
fixed_path = "/content/drive/MyDrive/multilingual_health_qa/submissions/submission_exp03_fixed.csv"
exp03.to_csv(fixed_path, index=False)
print(" Saved fixed file")

# Download it
files.download(fixed_path)
# Out:
# Empty strings remaining:
#   TargetRLF1: 0
#   TargetR1F1: 0
#   TargetLLM: 0
#  Saved fixed file

# %%
# EXPERIMENT 3 — Paste your Zindi score here
ZINDI_SCORE_EXP3 = 0.155076

update_zindi_score(EXP3, ZINDI_SCORE_EXP3)
print(f"Exp 3 score recorded: {ZINDI_SCORE_EXP3}")
# Out:
# ✓ Zindi score updated: exp03_flanT5base_lora_r16 = 0.155076
# Exp 3 score recorded: 0.155076

# %%
# Disable widget metadata saving
from tqdm import tqdm
import os
os.environ["TQDM_DISABLE"] = "0"

# Tell Jupyter not to save widget state
# %config Application.log_level = 'WARN'
